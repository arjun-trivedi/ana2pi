# %%
from __future__ import division
import atlib
wbng=atlib.init_bng((1.3,3,0.025),3)
w_uel=wbng['BINS_UE']

wsel_uel=[1.425,1.575,1.725,1.850,2.000,2.125,2.275,2.425,2.550,2.700,2.825,2.975]

Mppi=1.1
Mpi=0.139
binw_r2=[round(((x-Mpi)-Mppi)/14,2) for x in w_uel]
binw_r3=[round(((x-Mpi)-Mppi)/14,3) for x in w_uel]

fig=plt.figure(figsize=(18,8))

ax_r2=plt.subplot(211)
ax_r2.scatter(w_uel,binw_r2)
# ax_r2.set_xlabel("WBINS_UE [GeV]")
ax_r2.set_xticks(w_uel)
plt.xticks(rotation='vertical')
#plt.setp( ax_r2.get_xticklabels(), visible=False)
ax_r2.set_ylabel("M binw [MeV]")
plt.grid()

#mark upper edges of selected w bins
ymin=ax_r2.get_ylim()[0]
ymax=ax_r2.get_ylim()[1]
for i in wsel_uel:
    ymin=ax_r2.get_ylim()[0]
    ymax=ax_r2.get_ylim()[1]
    print ymin,ymax
    ax_r2.vlines(i,0.00+0.01,0.14-0.01)
    #plt.vlines(
#plt.show()

ax_r3=plt.subplot(212,sharex=ax_r2)
ax_r3.scatter(w_uel,binw_r3)
ax_r3.set_xlabel("WBINS_UE [GeV]")
ax_r3.set_xticks(w_uel)
plt.xticks(rotation='vertical')
ax_r3.set_ylabel("M binw [MeV]")
plt.grid()
# Out:
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14
# 0.0 0.14

# %%
wsel_uel=[1.425,1.575,1.725,1.850,2.000,2.125,2.275,2.425,2.550,2.700,2.825,2.975]

# %%
for i in wsel_uel:
    ymin=ax_r2.get_ylim()[0]
    ymax=ax_r2.get_ylim()[1]
    print ymin,ymax
    #ax_r2.vlines(i,ymin,ymax)
# Out:
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
# -2.0 2.5
