# %%
from __future__ import division
import atlib
wbng=atlib.init_bng((1.3,3,0.025),3)
w=wbng['BINS_UE']
# y=1.1
Mppi=1.1
Mpi=0.139
binw=[round(((x-Mpi)-Mppi)/14,2) for x in w]
#print binw
fig=plt.figure(figsize=(18,5))
ax=plt.subplot(111)
ax.scatter(w,binw)
ax.set_xlabel("WBINS_UE [GeV]")
ax.set_xticks(w)
plt.xticks(rotation='vertical')
#ax.set_xticklabels(w)
ax.set_ylabel("M binw [GeV]")
plt.grid()
