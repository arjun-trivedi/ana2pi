# %%
import rootnotes
ROOT.gROOT.ProcessLine(".L THnTool.C+")
from ROOT import THnTool
# Tools 
thntool=THnTool()

# %%
FIN=ROOT.TFile(os.path.join(os.environ['OBSDIR'],'siml','yield_sim_top1234.root'))

# %%
h5T=FIN.Get("%s/VST1/T/h5_UNPOL"%"1.25-1.75_1.975-2.000")
h5R=FIN.Get("%s/VST1/R/h5_UNPOL"%"1.25-1.75_1.975-2.000")
h5A=FIN.Get("%s/VST1/A/h5_UNPOL"%"1.25-1.75_1.975-2.000")
hT=thntool.GetBinContentDist(h5T)
hR=thntool.GetBinContentDist(h5R)
hA=thntool.GetBinContentDist(h5A)
c=rootnotes.default_canvas("c")
c.Divide(2,2)
c.cd(1)
hT.Draw()
c.cd(2)
hR.Draw()
c.cd(3)
hA.Draw()
c
# Out:
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# INFO:ROOT.TCanvas.Print] png file /tmp/tmpYbbGZc.png has been created
# <ROOT.TCanvas object ("c") at 0x55da8b0>

# %%
h5T=FIN.Get("%s/VST1/T/h5_UNPOL"%"1.75-2.25_1.975-2.000")
h5R=FIN.Get("%s/VST1/R/h5_UNPOL"%"1.75-2.25_1.975-2.000")
h5A=FIN.Get("%s/VST1/A/h5_UNPOL"%"1.75-2.25_1.975-2.000")
hT=thntool.GetBinContentDist(h5T)
hR=thntool.GetBinContentDist(h5R)
hA=thntool.GetBinContentDist(h5A)
c1=rootnotes.default_canvas("c1")
c1.Divide(2,2)
c1.cd(1)
hT.Draw()
c1.cd(2)
hR.Draw()
c1.cd(3)
hA.Draw()
c1
# Out:
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# INFO:ROOT.TCanvas.Print] png file /tmp/tmpXjZAVo.png has been created
# <ROOT.TCanvas object ("c1") at 0x4ca4cb0>

# %%
h5T=FIN.Get("%s/VST1/T/h5_UNPOL"%"2.25-2.75_1.975-2.000")
h5R=FIN.Get("%s/VST1/R/h5_UNPOL"%"2.25-2.75_1.975-2.000")
h5A=FIN.Get("%s/VST1/A/h5_UNPOL"%"2.25-2.75_1.975-2.000")
hT=thntool.GetBinContentDist(h5T,300,0,300)
hR=thntool.GetBinContentDist(h5R)
hA=thntool.GetBinContentDist(h5A)
c2=rootnotes.default_canvas("c2")
c2.Divide(2,2)
c2.cd(1)
hT.Draw()
c2.cd(2)
hR.Draw()
c2.cd(3)
hA.Draw()
c2
# Out:
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# WARNING:ROOT.TFile.Append] Replacing existing TH1: h5_UNPOL_BinContentDist (Potential memory leak).
# INFO:ROOT.TCanvas.Print] png file /tmp/tmp6FxuAq.png has been created
# <ROOT.TCanvas object ("c2") at 0x55e3110>
