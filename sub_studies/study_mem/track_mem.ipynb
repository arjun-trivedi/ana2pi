# %%
from __future__ import division
import atlib

# %%
"""
200M sim events: ST(1*3)+SR(4*3)
"""
atlib.plot_mem_stats("trackmem_200M",fit=True,plot_upper_limit=True)
# Out:
# Fit parameter= 0.293704241543
# 0.29370424154318236

# %%
"""
200M sim events: ST(1*3) only
"""
atlib.plot_mem_stats("trackmem_200M_ST_1_3",plot_upper_limit=True,fit=True)
# Out:
# Fit parameter= 0.207854581324
# 0.20785458132376267

# %%
"""
200M sim events: SR(4*3) only
"""
atlib.plot_mem_stats("trackmem_200M_SR_4_3",plot_upper_limit=True,fit=True)
# Out:
# Fit parameter= 0.12094522706
# 0.12094522706046898

# %%
"""
1B sim events: ST(1*3) only
+ 35552.149u 633.367s 11:19:39.95 88.7%   0+0k 1126376144+1480112io 6137pf+0w
+ d2pi.root: 683M
"""
atlib.plot_mem_stats("trackmem_1B_ST_1_3",fit=True)
# Out:
# Fit parameter= 0.146972934901
# 0.14697293490138252

# %%
"""
1B sim events: SR(4*3) only : stopped at 850M evts
+ 
+ 
"""
atlib.plot_mem_stats("memlog_1000M",fit=True)
# Out:
# Fit parameter= 0.140505658953
# 0.14050565895340417

# %%
0.22*sqrt(2000)
# Out:
# 9.838699100999076
