# %%
from __future__ import division
import atlib

# %%
"""
200M sim events: ST(1*3)+SR(4*3)
"""
atlib.plot_mem_stats("trackmem_200M",fit=True)
# Out:
# Fit parameter= 0.293704241543

# %%
"""
200M sim events: ST(1*3) only
"""
atlib.plot_mem_stats("trackmem_200M_ST_1_3")#,fit=True)
# Out:
# 0

# %%
"""
200M sim events: SR(4*3) only
"""
atlib.plot_mem_stats("memlog_200M",plot_upper_limit=False)#,fit=True)
# Out:
# 0
