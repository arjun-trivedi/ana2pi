# %%
import study_vars_tools as t
import shutil
from collections import OrderedDict

Q2WDIR='q2w2'
R=['exp_nmcor','exp_ymcor','sim_nmcor']
VAR=['mmppim']
TOP=[3]
hX=OrderedDict()
XMU=0.139
XCUT=0.2

#-- get X(d,Q2,W)
for r in R:
    t.init(Q2WDIR,0.6,0.025,TOP,VAR,[(0.0,0.5)],[(-0.03,0.03)],r)
    hX[r]=t.plot_var()

#-- create OUTDIR
VARdir="-".join(VAR)
Rdir = "-".join(R)
OUTDIR = os.path.join(Q2WDIR,VARdir,Rdir)
print "\n----OUTDIR",OUTDIR,"\n----"
if os.path.exists(OUTDIR):
    shutil.rmtree(OUTDIR)
os.makedirs(OUTDIR)
# Out:
# -----
# Importing d2pi.root -> DataFrame
# -----
# Going to use d2pi(exp_nmcor)
# File = /data/trivedia/e1f/study_vars/q2w2/exp_nmcor/recon/d2pi.root
# Variables to import directly into DataFrame= ['top', 'Q2', 'mmppim', 'W']
# Variables to be added later to the DataFrame []
# -----
# Topology selection: tops to be used =
# /usr/lib/python2.7/dist-packages/scipy/stats/distributions.py:30: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   import vonmises_cython
# /usr/lib/python2.7/dist-packages/scipy/stats/distributions.py:30: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import vonmises_cython
# /usr/local/lib/python2.7/dist-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#  [3]
# -----
# dbg:D before
#    top        Q2    mmppim         W
# 0    2  2.060979  0.617783  1.634772
# 1    4  2.022806  1.240676  1.533539
# 2    4  1.937134  1.384749  1.768826
# 3    1  2.041539  0.170137  1.850626
# 4    1  1.906316  0.182838  1.485198
# Evaluating (df['top']==3) ...
# dbg:D after
#     top        Q2    mmppim         W
# 7     3  1.974587  0.129434  1.395778
# 14    3  2.254417  0.054609  1.642965
# 23    3  2.165541  0.132350  1.654925
# 31    3  2.471119  0.287812  1.858904
# 34    3  2.296316  0.136401  1.442069
# -----
# Q2 binning
# -----
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# -----
# W binning
# -----
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# -----
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/study_vars/q2w2/exp_nmcor
# -----
# HOFT=
#  [Hist2D('mmppim_OFT')]
# HRES= [Hist2D('mmppim_RES')]
# -----
# Importing d2pi.root -> DataFrame
# -----
# Going to use d2pi(exp_ymcor)
# File = /data/trivedia/e1f/study_vars/q2w2/exp_ymcor/recon/d2pi.root
# Variables to import directly into DataFrame= ['top', 'Q2', 'mmppim', 'W']
# Variables to be added later to the DataFrame []
# -----
# Topology selection: tops to be used =
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_OFT (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_RES (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_02 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_03 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_04 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_05 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_06 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_07 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_08 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_09 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_10 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_11 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_12 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_13 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_14 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_15 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_16 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_17 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_18 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_19 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_20 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_21 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_22 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_23 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_24 (Potential memory leak).
#  [3]
# -----
# dbg:D before
#    top        Q2    mmppim         W
# 0    2  2.070127  0.594199  1.617025
# 1    4  2.012479  1.254598  1.548177
# 2    4  1.927142  1.395681  1.782109
# 3    1  2.052747  0.105721  1.838957
# 4    1  1.907208  0.180594  1.484136
# Evaluating (df['top']==3) ...
# dbg:D after
#     top        Q2    mmppim         W
# 7     3  1.976042  0.126442  1.392987
# 14    3  2.234432  0.104592  1.666878
# 24    3  2.175312  0.092513  1.643120
# 32    3  2.468731  0.288844  1.860637
# 35    3  2.302372  0.127860  1.430618
# -----
# Q2 binning
# -----
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# -----
# W binning
# -----
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# -----
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/study_vars/q2w2/exp_ymcor
# -----
# HOFT= [Hist2D('mmppim_OFT')]
# HRES= [Hist2D('mmppim_RES')]
# -----
# Importing d2pi.root -> DataFrame
# -----
# Going to use d2pi(sim_nmcor)
# File = /data/trivedia/e1f/study_vars/q2w2/sim_nmcor/recon/d2pi.root
# Variables to import directly into DataFrame= ['top', 'Q2', 'mmppim', 'W']
# Variables to be added later to the DataFrame []
# -----
# Topology selection: tops to be used =
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_OFT (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_RES (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_02 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_03 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_04 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_05 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_06 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_07 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_08 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_09 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_10 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_11 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_12 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_13 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_14 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_15 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_16 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_17 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_18 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_19 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_20 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_21 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_22 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_23 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: mmppim_01_24 (Potential memory leak).
#  [3]
# -----
# dbg:D before
#    top        Q2    mmppim         W
# 0    2  2.006469  0.600103  1.576777
# 1    4  2.499688  1.284225  1.856132
# 2    2  1.947310  0.632567  1.807989
# 3    1  1.939536  0.209779  1.688549
# 4    2  2.214607  0.832253  1.832791
# Evaluating (df['top']==3) ...
# dbg:D after
#     top        Q2    mmppim         W
# 21    3  1.907445  0.226236  1.714959
# 23    3  2.083103  0.172797  1.647785
# 27    3  2.026288  0.214895  1.917105
# 33    3  2.068304  0.273343  1.809399
# 36    3  2.007920  0.153100  1.725208
# -----
# Q2 binning
# -----
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# -----
# W binning
# -----
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# -----
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/study_vars/q2w2/sim_nmcor
# -----
# HOFT= [Hist2D('mmppim_OFT')]
# HRES= [Hist2D('mmppim_RES')]
#
# ----OUTDIR
#  q2w2/mmppim/exp_nmcor-exp_ymcor-sim_nmcor
# ----

# %%
fig=plt.figure(figsize=(20,20))
c=['red','green','blue']
nq2wbins=len(hX[R[0]]) # nq2wbins should be same for all R
ncols=6
nrows=nq2wbins/ncols
for ir,r in enumerate(R):
    for iq2w in range(nq2wbins):
        plt.subplot(nrows,ncols,iq2w+1)
        plt.title(hX[r][iq2w].GetTitle())
        hX[r][iq2w].linecolor=c[ir]
        rplt.hist(hX[r][iq2w],label=r)
        plt.vlines(XMU,plt.ylim()[0],plt.ylim()[1])
        plt.vlines(XCUT,plt.ylim()[0],plt.ylim()[1],linestyles='dashed')
        plt.legend(prop={'size':8})

# %%
r=plt.hist(np.random.normal(100,10,100000),bins=100,histtype='step')
r=plt.hist(np.random.normal(100,10,50000),bins=100,histtype='step')
