# %%
import study_vars_tools as t

hmm={}
for r in ['exp_nmcor','exp_ymcor','sim_nmcor']:
    t.init('q2w2',0.6,0.025,[2],
         ['M_ppip'],
         [(1.0,2.0)],
         [(-0.03,0.03)],
         r)
    hmm[r]=t.plot_var()
# Out:
# -----
# Importing d2pi.root -> DataFrame
# -----
# Going to use d2pi(exp_nmcor)
# File = /data/trivedia/e1f/study_MMs/q2w2/exp_nmcor/recon/d2pi.root
# Variables to import directly into DataFrame= ['top', 'Q2', 'M_ppip', 'W']
# Variables to be added later to the DataFrame []
# -----
# Topology selection: tops to be used =
#  [2]
# -----
# dbg:D before
#    top        Q2    M_ppip         W
# 0    2  2.060979  1.211119  1.634772
# 1    4  2.022806  1.240676  1.533539
# 2    4  1.937134  1.384749  1.768826
# 3    1  2.041539  1.466915  1.850626
# 4    1  1.906316  1.207505  1.485198
# Evaluating (df['top']==2) ...
# dbg:D after
#     top        Q2    M_ppip         W
# 0     2  2.060979  1.211119  1.634772
# 5     2  2.206150  1.358669  1.897379
# 9     2  1.942684  1.416700  1.692786
# 10    2  2.016910  1.244077  1.832641
# 11    2  2.220932  1.332941  1.753194
# -----
# Q2 binning
# -----
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# -----
# W binning
# -----
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# -----
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/study_MMs/q2w2/exp_nmcor
# -----
# HOFT=
# /usr/local/lib/python2.7/dist-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
#  [Hist2D('M_ppip_OFT')]
# HRES= [Hist2D('M_ppip_RES')]
# -----
# Importing d2pi.root -> DataFrame
# -----
# Going to use d2pi(exp_ymcor)
# File = /data/trivedia/e1f/study_MMs/q2w2/exp_ymcor/recon/d2pi.root
# Variables to import directly into DataFrame= ['top', 'Q2', 'M_ppip', 'W']
# Variables to be added later to the DataFrame []
# -----
# Topology selection: tops to be used =
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_OFT (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_RES (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_02 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_03 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_04 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_05 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_06 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_07 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_08 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_09 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_10 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_11 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_12 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_13 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_14 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_15 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_16 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_17 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_18 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_19 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_20 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_21 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_22 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_23 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_24 (Potential memory leak).
#  [2]
# -----
# dbg:D before
#    top        Q2    M_ppip         W
# 0    2  2.070127  1.211119  1.617025
# 1    4  2.012479  1.254598  1.548177
# 2    4  1.927142  1.395681  1.782109
# 3    1  2.052747  1.466915  1.838957
# 4    1  1.907208  1.207505  1.484136
# Evaluating (df['top']==2) ...
# dbg:D after
#     top        Q2    M_ppip         W
# 0     2  2.070127  1.211119  1.617025
# 5     2  2.214931  1.358669  1.883840
# 9     2  1.932451  1.416700  1.702788
# 10    2  2.005985  1.244077  1.840196
# 11    2  2.210862  1.332941  1.763959
# -----
# Q2 binning
# -----
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# -----
# W binning
# -----
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# -----
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/study_MMs/q2w2/exp_ymcor
# -----
# HOFT= [Hist2D('M_ppip_OFT')]
# HRES= [Hist2D('M_ppip_RES')]
# -----
# Importing d2pi.root -> DataFrame
# -----
# Going to use d2pi(sim_nmcor)
# File = /data/trivedia/e1f/study_MMs/q2w2/sim_nmcor/recon/d2pi.root
# Variables to import directly into DataFrame= ['top', 'Q2', 'M_ppip', 'W']
# Variables to be added later to the DataFrame []
# -----
# Topology selection: tops to be used =
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_OFT (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_RES (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_02 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_03 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_04 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_05 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_06 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_07 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_08 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_09 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_10 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_11 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_12 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_13 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_14 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_15 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_16 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_17 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_18 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_19 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_20 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_21 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_22 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_23 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: M_ppip_01_24 (Potential memory leak).
#  [2]
# -----
# dbg:D before
#    top        Q2    M_ppip         W
# 0    2  2.006469  1.212729  1.576777
# 1    4  2.499688  1.284225  1.856132
# 2    2  1.947310  1.412866  1.807989
# 3    1  1.939536  1.283014  1.688549
# 4    2  2.214607  1.279034  1.832791
# Evaluating (df['top']==2) ...
# dbg:D after
#    top        Q2    M_ppip         W
# 0    2  2.006469  1.212729  1.576777
# 2    2  1.947310  1.412866  1.807989
# 4    2  2.214607  1.279034  1.832791
# 5    2  2.215845  1.209541  1.705704
# 6    2  2.028025  1.257114  1.470504
# -----
# Q2 binning
# -----
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# -----
# W binning
# -----
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# -----
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/study_MMs/q2w2/sim_nmcor
# -----
# HOFT= [Hist2D('M_ppip_OFT')]
# HRES= [Hist2D('M_ppip_RES')]

# %%
print len(hmm['exp_ymcor'])
print hmm['exp_ymcor'][0].GetTitle()
# Out:
# 24
# M_ppip for Q2,W=[1.9000,2.5000],[1.3000,1.3250]

# %%
fig=plt.figure(figsize=(20,20))
c=['red','green','blue']
for ir,r in enumerate(['exp_nmcor','exp_ymcor','sim_nmcor']):
    #x=10
    for iq2w in range(24):
        plt.subplot(4,6,iq2w+1)
        plt.title(hmm[r][iq2w].GetTitle())
        hmm[r][iq2w].linecolor=c[ir]
        rplt.hist(hmm[r][iq2w],label=r)
        plt.vlines(1.232,plt.ylim()[0],plt.ylim()[1])
        #plt.vlines(0.2,plt.ylim()[0],plt.ylim()[1],linestyles='dashed')
        plt.legend(prop={'size':8})

# %%
r=plt.hist(np.random.normal(100,10,100000),bins=100,histtype='step')
r=plt.hist(np.random.normal(100,10,50000),bins=100,histtype='step')
