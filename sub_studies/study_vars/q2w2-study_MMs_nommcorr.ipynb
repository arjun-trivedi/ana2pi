# %%
import study_MMs_tools as t
t.init(['q2w2'],0.6,0.025,[2],0,
     ['mmppip'],
     [(0.0,0.5)],
     [(-0.03,0.03)])
# Out:
# dbg:mcor= 0
# dbg:mcor= 0
# dbg:else here
# dbg:using d2pi_nomomcorr.root
# Variables to import directly into DataFrame= ['top', 'Q2', 'mmppip', 'W']
# Variables to be added later to the DataFrame []
# Variables to import directly into DataFrame=
#  ['top', 'Q2', 'mmppip', 'W']
# Variables to be added later to the DataFrame []
# *** Going to keep only
#  [2] for dER and dSR ***
# Evaluating (df['top']==2) ...
# Evaluating (df['top']==2) ...
# 1.9 2.5 1.3 1.9 1 0.6
# *** Q2 binning ***
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# *** W binning ***
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# *** Q2 binning ***
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# *** W binning ***
# NWBINS=24,WBINW=0.0250 GeV
# ...

# %%
t.plot_q2w()

# %%
t.plot_MMs_comp()
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# dbg: dER before
#     top        Q2    mmppip         W
# 0     2  2.060979  0.388011  1.634772
# 5     2  2.206150  0.152484  1.897379
# 9     2  1.942684  0.096037  1.692786
# 10    2  2.016910  0.377259  1.832641
# 11    2  2.220932  0.273815  1.753194
# (dER['Q2']>=1.900000)&(dER['Q2']<2.500000)&(dER['W']>=1.300000)&(dER['W']<1.325000)
# dbg: dER after
#       top        Q2    mmppip         W
# 125     2  2.268216  0.106956  1.310676
# 2029    2  2.190226  0.034569  1.307969
# 2204    2  1.934488  0.064736  1.302652
# 2243    2  2.182615  0.102179  1.322951
# 3489    2  2.313343  0.162129  1.314606
# ...

# %%
t.plot_mm('mmppip')
#plt.vlines(0.139,plt.ylim()[0],plt.ylim()[1],colors='g',linestyles='dashed',linewidth=2)
#plt.vlines(0.145,plt.ylim()[0],plt.ylim()[1],colors='b',linestyles='dashed',linewidth=2)
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.Print] eps file test.eps has been created
# (dER['W']>=1.700000)&(dER['W']<2.000000)
# (dSR['W']>=1.700000)&(dSR['W']<2.000000)

# %%
t.plot_res(min_entries=500,use_frange=True)
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)

# %%
t.plot_electron_diagnostics()
# Out:
# debug= ['theta', 'p'] 1 theta_e p_e
# debug=
#  ['theta', 'p'] 2 Q2 theta_e
# debug=
#  ['theta', 'p'] 3 Q2 p_e
# debug=
#  ['theta', 'p'] 4 W theta_e
# debug=
#  ['theta', 'p'] 5 W p_e
# debug=
#  ['px', 'py'] 6 px_e py_e
# debug=
#  ['px', 'py'] 7 Q2 px_e
# debug=
#  ['px', 'py'] 8 Q2 py_e
# debug=
#  ['px', 'py'] 9 W px_e
# debug=
#  ['px', 'py'] 10 W py_e
