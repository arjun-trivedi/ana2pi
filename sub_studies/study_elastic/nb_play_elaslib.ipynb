# %%
import elaslib
import rootnotes
#nbins,xmin,xmax=46,14,60
nbins,xmin,xmax=120,30,150
hThrtcl=ROOT.TH1F("hThrtcl","hThrtcl",nbins,xmin,xmax)
hThrtcl.SetYTitle("#frac{d\sigma}{d\Omega} [\mu b]")
for ibin in range(nbins):
    theta=hThrtcl.GetBinLowEdge(ibin+1)
    if theta==0: continue
    #binc=elaslib.elas(5.499,theta)
    binc=elaslib.elasrad(0.188,theta,2.5*0.00577,1.1)
    #print "theta,xsec=",theta,binc
    hThrtcl.SetBinContent(ibin+1,binc)
    hThrtcl.SetBinError(ibin+1,0)
	#hThrtcl.GetXaxis().SetRangeUser(12,50)
c=rootnotes.default_canvas()
hThrtcl.Draw()
c
# Out:
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.Print] png file /tmp/tmp2J130C.png has been created
# <ROOT.TCanvas object ("icanvas") at 0x5a06b80>
