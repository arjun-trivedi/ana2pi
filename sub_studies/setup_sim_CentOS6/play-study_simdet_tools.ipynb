# %%
import study_simdet_tools as sdt
sdt.load_data(5497)
# Out:
# /usr/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/usr/lib/python2.7/dist-packages/scikits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from . import hashtable, tslib, lib
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:6: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from . import hashtable, tslib, lib
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.py:12: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   import pandas.algos as algos
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.py:12: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.algos as algos
# ...

# %%
mean,sigmas=sdt.get_detector_resolution_and_offset()
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5497/Delta_p_e.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5497/Delta_p_p.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5497/Delta_p_pip.png has been created
# ...

# %%
reload(sdt)
sdt.plot_detector_resolution_and_offset(mean,sigmas)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/legend.py:610: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x5998510>]
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   warnings.warn("Legend does not support %s\nUse proxy artist instead.\n\nhttp://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist\n" % (str(orig_handle),))
# /usr/lib/pymodules/python2.7/matplotlib/legend.py:610: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0xafbbc50>]
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   warnings.warn("Legend does not support %s\nUse proxy artist instead.\n\nhttp://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist\n" % (str(orig_handle),))
# ...

# %%
print sdt.dfR[['p_e','theta_e','phi_e','px_e','py_e','pz_e']].head()
# Out:
#         p_e    theta_e      phi_e      px_e      py_e      pz_e
# 0  2.971430  20.352964  14.693919  0.999671  0.262145  2.785917
# 1  3.282393  20.898117 -49.465851  0.760939 -0.889871  3.066465
# 2  3.281718  19.895340 -51.064896  0.701828 -0.868696  3.085851
# 3  3.463777  18.428743  -1.323890  1.094694 -0.025299  3.286146
# 4  3.453074  20.417309 -53.257519  0.720629 -0.965303  3.236140
# /usr/local/lib/python2.7/dist-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)

# %%
p=3.453074
theta=20.417309
phi=-53.257519
px=p*np.sin(np.deg2rad(theta))*np.cos(np.deg2rad(phi))
py=p*np.sin(np.deg2rad(theta))*np.sin(np.deg2rad(phi))
pz=p*np.cos(np.deg2rad(theta))
print px,py,pz,sqrt(px**2+py**2+pz**2)
# Out:
# 0.72062876206 -0.965303159528 3.23614030088 3.453074
