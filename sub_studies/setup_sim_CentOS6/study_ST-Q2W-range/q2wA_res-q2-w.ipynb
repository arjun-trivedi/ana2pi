# %% [markdown]
# ### Study resolution of Q2 and W for q2wA = [1.6,6.0],[1.2,1.3]
#
# #### Simulation parameters
# * Thrown Q2,W = [1.6,6.0] GeV2,[1.2,1.3] GeV
# * Beam energy = 5.499 GeV
#
# #### Event Reconstruction
# * Events reconstructed with 5.499 GeV i.e. BE-ST = BE-SR

# %%
import study_simdet_tools2 as t
t.init(['q2wA'],0.15,0.10,
     ['Q2',        'W',         'p_e',      'theta_e',    'pz_e',      'px_e',      'py_e'],
     [(-0.20,0.20),(-0.20,0.20),(-0.10,0.10),(-0.20,0.20),(-0.10,0.10),(-0.10,0.10),(-0.10,0.10)],
     [(-0.02,0.02),(-0.03,0.03),(-0.05,0.05),(-0.03,0.03),(-0.05,0.05),(-0.05,0.05),(-0.05,0.05)],
     [1,2,3,4])
# Out:
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# ERROR:ROOT.TTreeFormula.Compile]  Bad numerical expression : "0.2,0.2"
# ---------------------------------------------------------------------------
# ROOTError                                 Traceback (most recent call last)
# <ipython-input-1-adf9bf1b4ca7> in <module>()
#       4      [(-0.20,0.20),(-0.20,0.20),(-0.10,0.10),(-0.20,0.20),(-0.10,0.10),(-0.10,0.10),(-0.10,0.10)],
#       5      [(-0.02,0.02),(-0.03,0.03),(-0.05,0.05),(-0.03,0.03),(-0.05,0.05),(-0.05,0.05),(-0.05,0.05)],
# ----> 6      [1,2,3,4])
#
# /home/trivedia/CLAS/workspace/ana2pi/sub_studies/setup_sim_CentOS6/study_ST-Q2W-range/study_simdet_tools2.py in init(q2wdirs, q2binw, wbinw, tops, vars, hrange, frange)
#      61         for q2wdir in q2wdirs:
#      62                 f.append(os.path.join(DATADIR,q2wdir,'recon/d2pi.root'))
# ...

# %%
t.plot_q2w()

# %%
t.plot_res(min_entries=200)
# Out:
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: Q2_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: W_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: p_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: theta_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: pz_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: px_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: py_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: Q2_hdiff_02_01 (Potential memory leak).
# ...

# %%
t.plot_electron_diagnostics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d65684abd10> in <module>()
# ----> 1 t.plot_electron_diagnostics()
#
# NameError: name 't' is not defined
