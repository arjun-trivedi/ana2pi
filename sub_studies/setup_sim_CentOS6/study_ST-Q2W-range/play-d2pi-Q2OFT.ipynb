# %%
import rootnotes
datadir=os.environ['STUDY_STQ2WRANGE_DATADIR']
f = os.path.join(datadir,'q2w2/recon/d2pi.root')
arrT = root2array(f,'d2piTR/T/tT')#,stop=10000)#,start=1,stop=5)#,start=1,stop=5)#start=1,stop=2)
arrR = root2array(f,'d2piTR/R/tR')#,stop=10000)#,start=1,stop=5)#,start=1,stop=5)#start=1,mstop=2)

dT = pd.DataFrame(arrT)
dR = pd.DataFrame(arrR)

# %%
print dR[['p_e','p_e0']].head()
print dT[['p_e','p_e0']].head()
# Out:
#         p_e   p_e0
# 0  3.041749  5.499
# 1  2.871001  5.499
# 2  2.918250  5.499
# 3  3.377414  5.499
# 4  2.933939  5.499
#         p_e   p_e0
# 0  3.025991  5.499
# 1  2.891701  5.499
# 2  2.913752  5.499
# 3  3.379457  5.499
# 4  2.934486  5.499
# /usr/local/lib/python2.7/dist-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)

# %%
for d in (dT,dR):
			d['px_e']=d['p_e']*np.sin(np.deg2rad(d['theta_e']))*np.cos(np.deg2rad(d['phi_e']))
			d['py_e']=d['p_e']*np.sin(np.deg2rad(d['theta_e']))*np.sin(np.deg2rad(d['phi_e']))
			d['pz_e']=d['p_e']*np.cos(np.deg2rad(d['theta_e']))
			d['px_p']=d['p_p']*np.sin(np.deg2rad(d['theta_p']))*np.cos(np.deg2rad(d['phi_p']))
			d['py_p']=d['p_p']*np.sin(np.deg2rad(d['theta_p']))*np.sin(np.deg2rad(d['phi_p']))
			d['pz_p']=d['p_p']*np.cos(np.deg2rad(d['theta_p']))
			d['px_pip']=d['p_pip']*np.sin(np.deg2rad(d['theta_pip']))*np.cos(np.deg2rad(d['phi_pip']))
			d['py_pip']=d['p_pip']*np.sin(np.deg2rad(d['theta_pip']))*np.sin(np.deg2rad(d['phi_pip']))
			d['pz_pip']=d['p_pip']*np.cos(np.deg2rad(d['theta_pip']))
			d['px_pim']=d['p_pim']*np.sin(np.deg2rad(d['theta_pim']))*np.cos(np.deg2rad(d['phi_pim']))
			d['py_pim']=d['p_pim']*np.sin(np.deg2rad(d['theta_pim']))*np.sin(np.deg2rad(d['phi_pim']))
			d['pz_pim']=d['p_pim']*np.cos(np.deg2rad(d['theta_pim']))

# %%
Q2MIN=2.1
Q2MAX=2.105
Q2OFT=0.010
Q2RES=0.0105
sel=(dT['Q2']>=Q2MIN)&(dT['Q2']<Q2MAX)
plt.figure(figsize=(25,5))
ax=plt.subplot(141)
r=plt.hist(dT['Q2'][sel],bins=(100),alpha=0.5,histtype='stepfilled',label='ST',range=[Q2MIN-3*Q2RES,Q2MAX+3*Q2RES])
r=plt.hist(dR['Q2'][sel],bins=(100),alpha=0.5,histtype='stepfilled',label='SR',range=[Q2MIN-3*Q2RES,Q2MIN+3*Q2RES])
plt.vlines(Q2MIN+(Q2MAX-Q2MIN)/2,ax.get_ylim()[0],ax.get_ylim()[1],colors='b') #Mark ST mean
plt.vlines(Q2MIN+(Q2MAX-Q2MIN)/2-Q2OFT,ax.get_ylim()[0],ax.get_ylim()[1],colors='g')#Mark expected SR mean
plt.legend()
plt.subplot(142)
r=plt.hist(dT['W'][sel],bins=(100),alpha=0.5,histtype='stepfilled',label='ST',range=[1.5,1.7])
r=plt.hist(dR['W'][sel],bins=(100),alpha=0.5,histtype='stepfilled',label='SR',range=[1.5,1.7])
plt.legend()

# %%
# Q2t=-2*5.499*(dT['pz_e'][sel]-dT['p_e'][sel])
# Q2r=-2*5.499*(dR['pz_e'][sel]-dR['p_e'][sel])
Q2t=4*5.499*dT['p_e'][sel]*np.sin(np.deg2rad(dT['theta_e'][sel])/2)**2
Q2r=4*5.499*dR['p_e'][sel]*np.sin(np.deg2rad(dR['theta_e'][sel])/2)**2

r=plt.hist(Q2t,bins=100,histtype="stepfilled",alpha=0.5,range=[2.06,2.14])
r=plt.hist(Q2r,bins=100,histtype="stepfilled",alpha=0.5,range=[2.06,2.14])
plt.vlines(Q2MIN+(Q2MAX-Q2MIN)/2,ax.get_ylim()[0],ax.get_ylim()[1],colors='b') #Mark ST mean
plt.vlines(Q2MIN+(Q2MAX-Q2MIN)/2-Q2OFT,ax.get_ylim()[0],ax.get_ylim()[1],colors='g')#Mark expected SR mean

# %%
2*5.499*0.0002
# Out:
# 0.0021996
