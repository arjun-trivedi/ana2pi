# %% [markdown]
# #### Simulation parameters
# * Thrown Q2,W = [1.9,2.5] GeV2,[1.3,1.9] GeV
# * Beam energy = 5.499 GeV
#
# #### Event Reconstruction
# * Events reconstructed with 5.499 GeV i.e. BE-ST = BE-SR

# %%
import study_simdet_tools2 as t
t.init(['q2w2'],0.6,0.025,
     ['p_e',       'theta_e', 'phi_e',   'pz_e',    'px_e',    'py_e'],
     [(-0.10,0.10),(-0.2,0.2),(-1.0,1.0),(-0.10,0.10),(-0.10,0.10),(-0.10,0.10)],
     [(-0.03,0.03),(-0.1,0.1),(-1.0,1.0),(-0.03,0.03),(-0.03,0.03),(-0.03,0.03)],
     [1,2,3,4])
# Out:
# Branches to load into DataFrame= ['phi_p', 'theta_e', 'theta_p', 'top', 'p_e', 'p_pip', 'p_pim', 'Q2', 'phi_e', 'W', 'theta_pip', 'phi_pip', 'theta_pim', 'p_p', 'phi_pim']
# SEL_TOPS = (dR['top']==1)|(dR['top']==2)|(dR['top']==3)|(dR['top']==4)
# Simulated-Thrown Q2,W = [1.9100,2.5100]GeV^2,[1.3000,1.9000]GeV
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: p_e_OFT (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: p_e_RES (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: theta_e_OFT (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: theta_e_RES (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: phi_e_OFT (Potential memory leak).
# ...

# %%
t.plot_q2w()

# %%
t.plot_res(min_entries=500,use_frange=True)
# Out:
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: p_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: theta_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: phi_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: pz_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: px_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: py_e_hdiff_01_01 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: p_e_hdiff_01_02 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: theta_e_hdiff_01_02 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: phi_e_hdiff_01_02 (Potential memory leak).
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: pz_e_hdiff_01_02 (Potential memory leak).
# ...

# %%
t.plot_electron_diagnostics()
# Out:
# debug= ['theta', 'p'] 1 theta_e p_e
# debug=
#  ['theta', 'p'] 2 Q2 theta_e
# debug=
#  ['theta', 'p'] 3 Q2 p_e
# debug=
#  ['theta', 'p'] 4 W theta_e
# debug=
#  ['theta', 'p'] 5 W p_e
# debug=
#  ['px', 'py'] 6 px_e py_e
# debug=
#  ['px', 'py'] 7 Q2 px_e
# debug=
#  ['px', 'py'] 8 Q2 py_e
# debug=
#  ['px', 'py'] 9 W px_e
# debug=
#  ['px', 'py'] 10 W py_e
