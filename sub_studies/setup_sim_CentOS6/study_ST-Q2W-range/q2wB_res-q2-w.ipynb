# %% [markdown]
# ### Study resolution of Q2 and W for q2wB = [5.0,6.0] GeV2,[1.1,4.0] GeV
#
# #### Simulation parameters
# * Thrown Q2,W = [5.0,6.0] GeV2,[1.1,4.0] GeV
# * Beam energy = 5.499 GeV
#
# #### Event Reconstruction
# * Events reconstructed with 5.499 GeV i.e. BE-ST = BE-SR

# %%
import study_simdet_tools2 as t

# %%
t.init(['q2wB'],0.15,0.06,
     ['Q2','W','p_e','theta_e'],
     [(-0.2,0.2),(-0.2,0.2),(-0.1,0.1),(-0.2,0.2)],
     [(-0.02,0.02),(-0.03,0.03),(-0.05,0.05),(-0.03,0.03)],
     [1,2,3,4])
# Out:
# Branches to load into DataFrame= ['top', 'Q2', 'W', 'p_e', 'theta_e']
# SEL_TOPS = (dR['top']==1)|(dR['top']==2)|(dR['top']==3)|(dR['top']==4)
# Simulated-Thrown Q2,W = [5.00,6.00]GeV^2,[1.25,2.40]GeV
# *** Q2 binning ***
# NQ2BINS=7,Q2BINW=0.15 GeV^2
# ['5.00', '5.15', '5.30', '5.45', '5.60', '5.75', '5.90']
# ['5.15', '5.30', '5.45', '5.60', '5.75', '5.90', '6.05']
# *** W binning ***
# NWBINS=19,WBINW=0.06 GeV
# ['1.25', '1.31', '1.37', '1.43', '1.49', '1.55', '1.61', '1.67', '1.73', '1.79', '1.85', '1.91', '1.97', '2.03', '2.09', '2.15', '2.21', '2.27', '2.33']
# ['1.31', '1.37', '1.43', '1.49', '1.55', '1.61', '1.67', '1.73', '1.79', '1.85', '1.91', '1.97', '2.03', '2.09', '2.15', '2.21', '2.27', '2.33', '2.39']
# HOFT= [Hist2D('Q2_OFT'), Hist2D('W_OFT'), Hist2D('p_e_OFT'), Hist2D('theta_e_OFT')]
# HRES= [Hist2D('Q2_RES'), Hist2D('W_RES'), Hist2D('p_e_RES'), Hist2D('theta_e_RES')]
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/setup_sim_CentOS6/study_ST-Q2W-range/q2wB

# %%
t.plot_q2w()

# %%
t.plot_res(min_entries=500)
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)

# %%
t.plot_q2w_diagnostics()
