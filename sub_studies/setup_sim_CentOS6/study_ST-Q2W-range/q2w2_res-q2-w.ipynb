# %% [markdown]
# ### Study resolution of Q2 and W for q2w2 = [1.9,2.5] GeV2,[1.3,1.9] GeV
#
# #### Simulation parameters
# * Thrown Q2,W = [1.9,2.5] GeV2,[1.3,1.9] GeV
# * Beam energy = 5.499 GeV
#
# #### Event Reconstruction
# * Events reconstructed with 5.499 GeV i.e. BE-ST = BE-SR

# %%
import study_simdet_tools2 as t
t.init(['q2w2'],0.6,0.025,[1,2,3,4],
     ['Q2','W'],
     [(-0.20,0.20),(-0.20,0.20)],
     [(-0.02,0.02),(-0.02,0.02)])
# Out:
# Variables to import directly into DataFrame= ['top', 'Q2', 'W']
# Variables to be added later to the DataFrame []
# Variables to import directly into DataFrame=
#  ['top', 'Q2', 'W']
# Variables to be added later to the DataFrame []
# SEL_TOPS = (dR['top']==1)|(dR['top']==2)|(dR['top']==3)|(dR['top']==4)
# *** Q2 binning ***
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# *** W binning ***
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# *** Q2 binning ***
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.9000', '2.5000']
# *** W binning ***
# NWBINS=24,WBINW=0.0250 GeV
# ['1.3000', '1.3250', '1.3500', '1.3750', '1.4000', '1.4250', '1.4500', '1.4750', '1.5000', '1.5250', '1.5500', '1.5750', '1.6000', '1.6250', '1.6500', '1.6750', '1.7000', '1.7250', '1.7500', '1.7750', '1.8000', '1.8250', '1.8500', '1.8750', '1.9000']
# Simulated-Thrown Q2,W = [1.9000,2.5000]GeV^2,[1.3000,1.9000]GeV
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/setup_sim_CentOS6/study_ST-Q2W-range/q2w2
# HOFT= [Hist2D('Q2_OFT'), Hist2D('W_OFT')]
# HRES= [Hist2D('Q2_RES'), Hist2D('W_RES')]

# %%
t.plot_q2w()

# %%
t.plot_res(min_entries=500,use_frange=1)
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
