# %%
from __future__ import division

from root_numpy import root2array, root2rec, tree2rec
from root_numpy.testdata import get_filepath
from rootpy.plotting import Hist2D, Hist
from rootpy.plotting import root2matplotlib as rplt
from rootpy.interactive import wait
import ROOT
import rootnotes

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from math import *

import os

datadir=os.environ['STUDY_STQ2WRANGE_DATADIR']
f = os.path.join(datadir,'q2wA_022114/recon/d2pi.root')
arrT = root2array(f,'d2piTR/T/tT')#,stop=10000)#,start=1,stop=5)#,start=1,stop=5)#start=1,stop=2)
arrR = root2array(f,'d2piTR/R/tR')#,stop=10000)#,start=1,stop=5)#,start=1,stop=5)#start=1,stop=2)

dT = pd.DataFrame(arrT)
dR = pd.DataFrame(arrR)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-83a8a1864a19> in <module>()
#       3 from root_numpy import root2array, root2rec, tree2rec
#       4 from root_numpy.testdata import get_filepath
# ----> 5 from rootpy.plotting import Hist2D, Hist
#       6 from rootpy.plotting import root2matplotlib as rplt
#       7 from rootpy.interactive import wait
#
# /usr/local/lib/python2.7/dist-packages/rootpy/__init__.pyc in <module>()
#       9
#      10 # Needed for "from rootpy import QROOT" by other modules
# ---> 11 from .util import quickroot as QROOT
#      12 from . import defaults
#      13 from .core import Object
#
# /usr/local/lib/python2.7/dist-packages/rootpy/util/quickroot.py in <module>()
#       6 The main principle is that appropriate dictionaries need to be loaded.
#       7 """
# ----> 8 import ROOT
#       9
#      10 from .. import log; log = log[__name__]
#
# ImportError: No module named ROOT
# /usr/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/usr/lib/python2.7/dist-packages/scikits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)

# %%
dQ2=dfT['Q2']-dfR['Q2']
dW=dfT['W']-dfR['W']

# %%
ret=plt.hist(dQ2,100,range=[-0.1,0.1])
ret=plt.hist(dW,100,range=[-0.1,0.1])

# %%
ret=plt.hist(dfR['W'],100,range=[1.1,1.5])
ret=plt.hist(dfT['W'],100,range=[1.1,1.5])

# %%
sels = [(dfT['Q2']>1)&(dfT['Q2']<=2),(dfT['Q2']>2)&(dfT['Q2']<=3),
        (dfT['Q2']>3)&(dfT['Q2']<=4),(dfT['Q2']>4)&(dfT['Q2']<=5),
        (dfT['Q2']>5)]
np.random.randint(0,10)
# Out:
# 1

# %%
c = rootnotes.default_canvas("c%d"%np.random.randint(0,10))
c.Divide(len(sels),2)
h=[[[],[]] for i in range(len(sels))]
print h
for isel in range(len(sels)):
    dQ2=dfT['Q2'][sels[isel]]-dfR['Q2'][sels[isel]]
    dW=dfT['W'][sels[isel]]-dfR['W'][sels[isel]]
    h[isel][0]=Hist(100,-0.1,0.1)
    h[isel][1]=Hist(100,-0.1,0.1)
    c.cd(isel*2+1)
    h[isel][0].fill_array(dQ2)
    h[isel][0].Draw()
    c.cd(isel*2+2)
    h[isel][1].fill_array(dW)
    h[isel][1].Draw()
    #fig,ax=plt.subplots(1,2,figsize=(14,4))
    #ret=ax[0].hist(dQ2,100,range=[-0.1,0.1])
    #ret=ax[1].hist(dW,100,range=[-0.1,0.1])
c
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.Print] png file /tmp/tmp48xmlQ.png has been created
# [[[], []], [[], []], [[], []], [[], []], [[], []]]
# <ROOT.TCanvas object ("c6") at 0x6093090>

# %%
0=,.dfi-
