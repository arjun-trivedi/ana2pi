# %%
import study_simdet_tools as sdt
sdt.load_data(5497)
dfT=sdt.dfT
dfR=sdt.dfR
sdt.plot_kinematics()
# Out:
# /usr/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/usr/lib/python2.7/dist-packages/scikits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from . import hashtable, tslib, lib
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:6: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from . import hashtable, tslib, lib
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.py:12: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   import pandas.algos as algos
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.py:12: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.algos as algos
# ...

# %%
#reload(sdt)
means,sgmas=sdt.get_detector_resolution_and_offset()
sdt.plot_detector_resolution_and_offset(means,sgmas)
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5497/Delta_p_e.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5497/Delta_p_p.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5497/Delta_p_pip.png has been created
# ...

# %%
"""
+ Compare Electron Vertex positions for ST & SR data; use Topology 1
+ See following Code Blocks for p,pip,pim Vertex Position comparison
    - Note in MCTK, only e- vtx. positions are available. I simply copied them for p,pip,pim)
"""
COLS=['vx_e','vy_e','vz_e']
XMINS=[-1,-1,-30]
XMAXS=[1,1,-20]
sel=(dfR['top']==1)
plt.figure(figsize=(20,10))
for icol in range(len(COLS)):
    plt.subplot(1,3,icol+1)
    sel=(dfR['top']==1)
    plt.hist(dfT[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='ST-%s'%COLS[icol])
    plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    #plt.xlabel(fontsize=18)
    plt.legend(loc='best')

# %%
from rootpy.plotting import Hist2D, Hist
from rootpy.interactive import wait
import ROOT

COLS=['vx_e','vy_e','vz_e']
XMINS=[-1,-1,-30]
XMAXS=[1,1,-20]
NCOLS=len(COLS)
NBINS=100
sel=(dfR['top']==1)
plt.figure(figsize=(15,10))
hs=[]
cvx=ROOT.TCanvas("vx","vx")
cvx.Divide(1,NCOLS)
for icol in range(NCOLS):
    plt.subplot(1,NCOLS,icol+1)
    cvx.cd(icol+1)
    sel=(dfR['top']==1)
    plt.hist(dfT[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='ST-%s'%COLS[icol])
    plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    delta=dfR[COLS[icol]][sel]-dfT[COLS[icol]][sel]
    #plt.hist(delta,bins=100,range=(-1,1),alpha=0.5,label='$\Delta$-%s'%COLS[icol])
    hs.append(Hist(NBINS,-1,1))
    hs[icol].SetName('#Delta-%s'%COLS[icol])
    hs[icol].fill_array(delta)
    hs[icol].Fit("gaus")
    hs[icol].Draw()
    #plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    plt.legend(loc='best')
# Out:
# WARNING:ROOT.TCanvas.Constructor] Deleting canvas with same name: vx

# %%
COLS=['theta_e','phi_e']
XMINS=[15,-180]
XMAXS=[30,180]
NCOLS=len(COLS)
NBINS=100
sel=(dfR['top']==1)
plt.figure(figsize=(15,5))
hs=[]
cangles=ROOT.TCanvas("angles","angles")
cangles.Divide(1,NCOLS)
for icol in range(NCOLS):
    plt.subplot(1,NCOLS,icol+1)
    cangles.cd(icol+1)
    sel=(dfR['top']==1)
    plt.hist(dfT[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='ST-%s'%COLS[icol])
    plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    delta=dfR[COLS[icol]][sel]-dfT[COLS[icol]][sel]
    #plt.hist(delta,bins=100,range=(-1,1),alpha=0.5,label='$\Delta$-%s'%COLS[icol])
    hs.append(Hist(NBINS,-1,1))
    hs[icol].SetName('#Delta-%s'%COLS[icol])
    hs[icol].fill_array(delta)
    hs[icol].Fit("gaus")
    hs[icol].Draw()
    #plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    plt.legend(loc='best')
# Out:
# WARNING:ROOT.TCanvas.Constructor] Deleting canvas with same name: angles

# %%
from rootpy.plotting import Hist2D, Hist
from rootpy.interactive import wait
import ROOT

COLS=['vx_e','vy_e','vz_e']
XMINS=[-1,-1,-30]
XMAXS=[1,1,-20]
NCOLS=len(COLS)
NBINS=100
sel=(dfR['top']==1)
plt.figure(figsize=(15,10))
hs=[]
cvx=ROOT.TCanvas("vx","vx")
cvx.Divide(1,NCOLS)
for icol in range(NCOLS):
    plt.subplot(1,NCOLS,icol+1)
    cvx.cd(icol+1)
    sel=(dfR['top']==1)
    plt.hist(dfT[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='ST-%s'%COLS[icol])
    plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    delta=dfR[COLS[icol]][sel]-dfT[COLS[icol]][sel]
    #plt.hist(delta,bins=100,range=(-1,1),alpha=0.5,label='$\Delta$-%s'%COLS[icol])
    hs.append(Hist(NBINS,-1,1))
    hs[icol].SetName('#Delta-%s'%COLS[icol])
    hs[icol].fill_array(delta)
    hs[icol].Fit("gaus")
    hs[icol].Draw()
    #plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    plt.legend(loc='best')

# %%
"""
+ Compare Electron Vertex positions for ST & SR data; use Topology 1
+ See following Code Blocks for p,pip,pim Vertex Position comparison
    - Note in MCTK, only e- vtx. positions are available. I simply copied them for p,pip,pim)
"""
COLS=['vx_p','vy_p','vz_p']
XMINS=[-1,-1,-30]
XMAXS=[1,1,-20]
sel=(dfR['top']==1)
plt.figure(figsize=(20,10))
for icol in range(len(COLS)):
    plt.subplot(1,3,icol+1)
    sel=(dfR['top']==1)
    plt.hist(dfT[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='ST-%s'%COLS[icol])
    plt.hist(dfR[COLS[icol]][sel],bins=100,range=(XMINS[icol],XMAXS[icol]),alpha=0.5,label='SR-%s'%COLS[icol])
    #plt.xlabel(fontsize=18)
    plt.legend(loc='best')

# %%
x=dfR['vz_e'][sel]-dfR['vz_p'][sel]
plt.hist(x,bins=100,range=(-1,1))
# Out:
# (array([102, 113, 114, 125, 143, 159, 169, 160, 182, 156, 216, 187, 246,
#        229, 258, 255, 285, 256, 294, 314, 330, 351, 380, 383, 366, 415,
#        396, 439, 433, 476, 472, 501, 467, 518, 476, 532, 565, 601, 612,
#        584, 649, 680, 691, 688, 682, 701, 726, 731, 733, 715, 697, 716,
#        743, 728, 719, 666, 708, 670, 686, 605, 638, 615, 659, 593, 562,
#        525, 538, 479, 478, 502, 446, 451, 431, 396, 384, 408, 405, 360,
#        358, 352, 303, 302, 296, 256, 273, 260, 210, 224, 185, 199, 194,
#        166, 166, 157, 158, 138, 135, 116, 117, 115]),
#  array([-1.  , -0.98, -0.96, -0.94, -0.92, -0.9 , -0.88, -0.86, -0.84,
#        -0.82, -0.8 , -0.78, -0.76, -0.74, -0.72, -0.7 , -0.68, -0.66,
#        -0.64, -0.62, -0.6 , -0.58, -0.56, -0.54, -0.52, -0.5 , -0.48,
#        -0.46, -0.44, -0.42, -0.4 , -0.38, -0.36, -0.34, -0.32, -0.3 ,
#        -0.28, -0.26, -0.24, -0.22, -0.2 , -0.18, -0.16, -0.14, -0.12,
# ...
