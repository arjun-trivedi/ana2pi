# %%
import study_simdet_tools as sdt
sdt.load_data(5492)
sdt.plot_q2w()
sdt.plot_kinematics()
means,sgmas=sdt.get_detector_resolution_and_offset()
# Out:
# /usr/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/usr/lib/python2.7/dist-packages/scikits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from . import hashtable, tslib, lib
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:6: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from . import hashtable, tslib, lib
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.py:12: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   import pandas.algos as algos
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.py:12: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.algos as algos
# /usr/local/lib/python2.7/dist-packages/pandas/core/index.py:10: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   import pandas.index as _index
# /usr/local/lib/python2.7/dist-packages/pandas/core/index.py:10: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.index as _index
# /usr/local/lib/python2.7/dist-packages/pandas/sparse/array.py:16: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from pandas._sparse import BlockIndex, IntIndex
# 	Load data
#
#
# 	Look at Q2 Vs. W
# /usr/local/lib/python2.7/dist-packages/pandas/sparse/array.py:16: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from pandas._sparse import BlockIndex, IntIndex
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:24: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   import pandas.parser as _parser
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:24: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.parser as _parser
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# 	Plot Reconstructed kinematics of e,p,pip,pim at the e vertex
# 	Compare with Thrown kinematics
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_p_e.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_p_p.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_p_pip.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_p_pim.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_px_e.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_py_e.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_pz_e.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_px_p.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_py_p.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_pz_p.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_px_pip.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_py_pip.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_pz_pip.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_px_pim.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_py_pim.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_pz_pim.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_Q2.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_W.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_M_ppip.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_M_ppim.png has been created
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_M_pippim.png has been created
# WARNING:ROOT.Fit] Fit data is empty
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_mm2ppippim.png has been created
# WARNING:ROOT.Fit] Fit data is empty
# WARNING:ROOT.Fit] Fit data is empty
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_mmppip.png has been created
# WARNING:ROOT.Fit] Fit data is empty
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_mmppim.png has been created
# WARNING:ROOT.Fit] Fit data is empty
# INFO:ROOT.TCanvas.Print] png file /e1f.sim2pi.datadir/setup_sim_CentOS6/gpppars/try1/q2w2_gpptest_14_011914/recon/be5492/Delta_mmpippim.png has been created
#     Plot (Simulated)detector "Offset" & "Resolution"
#     Offset:     Mean of ST-SR distribution
#     Resolution: RMS of ST-SR distribution

# %%
reload(sdt)
sdt.plot_detector_resolution_and_offset(means,sgmas)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/axes.py:4486: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
calc
