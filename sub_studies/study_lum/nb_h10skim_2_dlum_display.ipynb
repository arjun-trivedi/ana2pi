# %%
import glob#,subprocess
from subprocess import Popen, PIPE, STDOUT

# %%
#os.listdir(os.path.join(os.environ['H10SKIMDIR_EXP']))
h10lstl=glob.glob("/home/trivedia/ongoing/e1f_allruns_h10lst/*.lst")
h10lstl=sort(h10lstl)
#print h10lstl
for h10lst in h10lstl:
    runnum=int(h10lst.split("/")[5].split(".")[0])
    if runnum>37661:continue
    #print runnum   
    
    #cmd=["proc_h10","-i",h10lst,"-t","e1f:exp:2pi","-p","proc_lum","-o","%d.root"%runnum]#,"-l",str(use_q2w_elist),"-m",f_q2w_el,"-q",q2w]
    #print ">>>",cmd
    #subprocess.check_output(cmd)
    #subprocess.call(cmd)
    
    cmd="proc_h10 -i %s -t e1f:exp:2pi  -p lum -o %s/%d.root"%(h10lst,os.environ['STUDY_LUM_DATADIR'],runnum)
    print "Going to process runnum %d"%runnum
    print ">%s"%cmd
    p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
    stdout=p.stdout.read()
    #stderr=p.stderr
    print stdout#,stderr
        
    #proc_h10 -i h10.lst -t e1f:exp:2pi -p lum -o test_lum.root
# Out:
# Going to process runnum 37658
# >proc_h10 -i /home/trivedia/ongoing/e1f_allruns_h10lst/37658.lst -t e1f:exp:2pi  -p lum -o /data/trivedia/e1f/study_lum/lum_37658.root
# Info in <proc_h10::main()>:
#
# Info in <proc_h10>: Not going to use q2w_elist
#
# Info in <proc_h10>: h10lst=/home/trivedia/ongoing/e1f_allruns_h10lst/37658.lst,h10type=e1f:exp:2pi,procorder=lum,fout=/data/trivedia/e1f/study_lum/lum_37658.root,nentries=1000000000
# Info in <proc_h10::SetupProcs()>: procorder = lum
#
# Collection name='TObjArray', class='TObjArray', size=16
#  TObjString = lum
# Info in <EpProcessor::EpProcessor()>: lum isFirstProc!
#
# Info in <EpProcessor::EpProcessor()>: eid isFirstProc!
#
# Info in <ProcEid::ProcEid()>: dH10.expt==e1f && eidParFileFound=true. Will use goodE()
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Number of entries in Chain =  3313868
# Info in <H10Looper::Loop>: Number of entries to processess =  3313868
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 0(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a00.root)
# Info in <H10Looper::Loop>:  0.00% entries processed
# Info in <H10Looper::Loop>: Total memory used = 32MB
# Info in <H10Looper::Loop>: Processing entry# 100000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a00.root)
# Info in <H10Looper::Loop>:  3.02% entries processed
# Info in <H10Looper::Loop>: Total memory used = 26MB
# Info in <H10Looper::Loop>: Processing entry# 200000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a00.root)
# Info in <H10Looper::Loop>:  6.04% entries processed
# Info in <H10Looper::Loop>: Total memory used = 11MB
# Info in <H10Looper::Loop>: Processing entry# 300000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a00.root)
# Info in <H10Looper::Loop>:  9.05% entries processed
# Info in <H10Looper::Loop>: Total memory used = 0MB
# Info in <H10Looper::Loop>: Processing entry# 400000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a00.root)
# Info in <H10Looper::Loop>: 12.07% entries processed
# Info in <H10Looper::Loop>: Total memory used = 17MB
# Info in <H10Looper::Loop>: Processing entry# 500000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a00.root)
# Info in <H10Looper::Loop>: 15.09% entries processed
# Info in <H10Looper::Loop>: Total memory used = -12MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 600000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a01.root)
# Info in <H10Looper::Loop>: 18.11% entries processed
# Info in <H10Looper::Loop>: Total memory used = -20MB
# Info in <H10Looper::Loop>: Processing entry# 700000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a01.root)
# Info in <H10Looper::Loop>: 21.12% entries processed
# Info in <H10Looper::Loop>: Total memory used = 7MB
# Info in <H10Looper::Loop>: Processing entry# 800000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a01.root)
# Info in <H10Looper::Loop>: 24.14% entries processed
# Info in <H10Looper::Loop>: Total memory used = 28MB
# Info in <H10Looper::Loop>: Processing entry# 900000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a01.root)
# Info in <H10Looper::Loop>: 27.16% entries processed
# Info in <H10Looper::Loop>: Total memory used = 23MB
# Info in <H10Looper::Loop>: Processing entry# 1000000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a01.root)
# Info in <H10Looper::Loop>: 30.18% entries processed
# Info in <H10Looper::Loop>: Total memory used = 8MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 1100000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a02.root)
# Info in <H10Looper::Loop>: 33.19% entries processed
# Info in <H10Looper::Loop>: Total memory used = -24MB
# Reading eid pars from /home/trivedia/CLAS/workspace/ana2pi/eid/eid.exp.out
# qcurr=0.09,qprev=0.05,deltaq=0.04,totalQ=0.04qcurr=0.14,qprev=0.09,deltaq=0.04,totalQ=0.09qcurr=0.18,qprev=0.14,deltaq=0.04,totalQ=0.13qcurr=0.22,qprev=0.18,deltaq=0.04,totalQ=0.17qcurr=0.26,qprev=0.22,deltaq=0.04,totalQ=0.21qcurr=0.31,qprev=0.26,deltaq=0.04,totalQ=0.26qcurr=0.35,qprev=0.31,deltaq=0.04,totalQ=0.30qcurr=0.39,qprev=0.35,deltaq=0.04,totalQ=0.34qcurr=0.43,qprev=0.39,deltaq=0.04,totalQ=0.38qcurr=0.48,qprev=0.43,deltaq=0.04,totalQ=0.43qcurr=0.52,qprev=0.48,deltaq=0.04,totalQ=0.47qcurr=0.56,qprev=0.52,deltaq=0.04,totalQ=0.51qcurr=0.61,qprev=0.56,deltaq=0.04,totalQ=0.56qcurr=0.65,qprev=0.61,deltaq=0.04,totalQ=0.60qcurr=0.69,qprev=0.65,deltaq=0.04,totalQ=0.64qcurr=0.74,qprev=0.69,deltaq=0.04,totalQ=0.69qcurr=0.78,qprev=0.74,deltaq=0.04,totalQ=0.73qcurr=0.82,qprev=0.78,deltaq=0.04,totalQ=0.77qcurr=0.86,qprev=0.82,deltaq=0.04,totalQ=0.81qcurr=0.91,qprev=0.86,deltaq=0.04,totalQ=0.86qcurr=0.95,qprev=0.91,deltaq=0.04,totalQ=0.90qcurr=0.99,qprev=0.95,deltaq=0.04,totalQ=0.94qcurr=1.03,qprev=0.99,deltaq=0.04,totalQ=0.98qcurr=1.08,qprev=1.03,deltaq=0.04,totalQ=1.03qcurr=1.12,qprev=1.08,deltaq=0.04,totalQ=1.07qcurr=1.16,qprev=1.12,deltaq=0.04,totalQ=1.11qcurr=1.20,qprev=1.16,deltaq=0.04,totalQ=1.15qcurr=1.25,qprev=1.20,deltaq=0.04,totalQ=1.20qcurr=1.29,qprev=1.25,deltaq=0.04,totalQ=1.24qcurr=1.33,qprev=1.29,deltaq=0.04,totalQ=1.28qcurr=1.37,qprev=1.33,deltaq=0.04,totalQ=1.32qcurr=1.41,qprev=1.37,deltaq=0.04,totalQ=1.36qcurr=1.46,qprev=1.41,deltaq=0.04,totalQ=1.41qcurr=1.50,qprev=1.46,deltaq=0.04,totalQ=1.45qcurr=1.54,qprev=1.50,deltaq=0.04,totalQ=1.49qcurr=1.58,qprev=1.54,deltaq=0.04,totalQ=1.53qcurr=1.63,qprev=1.58,deltaq=0.04,totalQ=1.58qcurr=1.67,qprev=1.63,deltaq=0.04,totalQ=1.62qcurr=1.67,qprev=1.67,deltaq=0.01,totalQ=1.62qcurr=1.72,qprev=1.67,deltaq=0.04,totalQ=1.67qcurr=1.76,qprev=1.72,deltaq=0.04,totalQ=1.71qcurr=1.80,qprev=1.76,deltaq=0.04,totalQ=1.75qcurr=1.84,qprev=1.80,deltaq=0.04,totalQ=1.79qcurr=1.88,qprev=1.84,deltaq=0.04,totalQ=1.83qcurr=1.92,qprev=1.88,deltaq=0.04,totalQ=1.87qcurr=1.97,qprev=1.92,deltaq=0.04,totalQ=1.92qcurr=2.01,qprev=1.97,deltaq=0.04,totalQ=1.96qcurr=2.05,qprev=2.01,deltaq=0.04,totalQ=2.00qcurr=2.09,qprev=2.05,deltaq=0.04,totalQ=2.04qcurr=2.11,qprev=2.09,deltaq=0.02,totalQ=2.06qcurr=2.14,qprev=2.11,deltaq=0.03,totalQ=2.09qcurr=2.18,qprev=2.14,deltaq=0.04,totalQ=2.13qcurr=2.22,qprev=2.18,deltaq=0.04,totalQ=2.17qcurr=2.26,qprev=2.22,deltaq=0.04,totalQ=2.21qcurr=2.30,qprev=2.26,deltaq=0.04,totalQ=2.25qcurr=2.34,qprev=2.30,deltaq=0.04,totalQ=2.29qcurr=2.38,qprev=2.34,deltaq=0.04,totalQ=2.33qcurr=2.43,qprev=2.38,deltaq=0.04,totalQ=2.38qcurr=2.47,qprev=2.43,deltaq=0.04,totalQ=2.42qcurr=2.51,qprev=2.47,deltaq=0.04,totalQ=2.46qcurr=2.55,qprev=2.51,deltaq=0.04,totalQ=2.50qcurr=2.59,qprev=2.55,deltaq=0.04,totalQ=2.54qcurr=2.63,qprev=2.59,deltaq=0.04,totalQ=2.58qcurr=2.67,qprev=2.63,deltaq=0.04,totalQ=2.62qcurr=2.71,qprev=2.67,deltaq=0.04,totalQ=2.66qcurr=2.75,qprev=2.71,deltaq=0.04,totalQ=2.70qcurr=2.80,qprev=2.75,deltaq=0.04,totalQ=2.75qcurr=2.84,qprev=2.80,deltaq=0.04,totalQ=2.79qcurr=2.88,qprev=2.84,deltaq=0.04,totalQ=2.83qcurr=2.92,qprev=2.88,deltaq=0.04,totalQ=2.87qcurr=2.96,qprev=2.92,deltaq=0.04,totalQ=2.91qcurr=3.00,qprev=2.96,deltaq=0.04,totalQ=2.95qcurr=3.04,qprev=3.00,deltaq=0.04,totalQ=2.99qcurr=3.09,qprev=3.04,deltaq=0.04,totalQ=3.04qcurr=3.15,qprev=3.09,deltaq=0.06,totalQ=3.10qcurr=3.21,qprev=3.15,deltaq=0.06,totalQ=3.16qcurr=3.27,qprev=3.21,deltaq=0.06,totalQ=3.22qcurr=3.33,qprev=3.27,deltaq=0.06,totalQ=3.28qcurr=3.39,qprev=3.33,deltaq=0.06,totalQ=3.34qcurr=3.45,qprev=3.39,deltaq=0.06,totalQ=3.40qcurr=3.51,qprev=3.45,deltaq=0.06,totalQ=3.46qcurr=3.58,qprev=3.51,deltaq=0.06,totalQ=3.53qcurr=3.64,qprev=3.58,deltaq=0.06,totalQ=3.59qcurr=3.70,qprev=3.64,deltaq=0.06,totalQ=3.65qcurr=3.76,qprev=3.70,deltaq=0.06,totalQ=3.71qcurr=3.83,qprev=3.76,deltaq=0.06,totalQ=3.78qcurr=3.89,qprev=3.83,deltaq=0.06,totalQ=3.84qcurr=3.95,qprev=3.89,deltaq=0.06,totalQ=3.90qcurr=4.01,qprev=3.95,deltaq=0.06,totalQ ...
# Info in <H10Looper::Loop>: 36.21% entries processed
# Info in <H10Looper::Loop>: Total memory used = -43MB
# Info in <H10Looper::Loop>: Processing entry# 1300000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a02.root)
# Info in <H10Looper::Loop>: 39.23% entries processed
# Info in <H10Looper::Loop>: Total memory used = 0MB
# Info in <H10Looper::Loop>: Processing entry# 1400000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a02.root)
# Info in <H10Looper::Loop>: 42.25% entries processed
# Info in <H10Looper::Loop>: Total memory used = 19MB
# Info in <H10Looper::Loop>: Processing entry# 1500000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a02.root)
# Info in <H10Looper::Loop>: 45.26% entries processed
# Info in <H10Looper::Loop>: Total memory used = 19MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 1600000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a03.root)
# Info in <H10Looper::Loop>: 48.28% entries processed
# Info in <H10Looper::Loop>: Total memory used = -56MB
# Info in <H10Looper::Loop>: Processing entry# 1700000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a03.root)
# Info in <H10Looper::Loop>: 51.30% entries processed
# Info in <H10Looper::Loop>: Total memory used = -1MB
# Info in <H10Looper::Loop>: Processing entry# 1800000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a03.root)
# Info in <H10Looper::Loop>: 54.32% entries processed
# Info in <H10Looper::Loop>: Total memory used = 34MB
# Info in <H10Looper::Loop>: Processing entry# 1900000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a03.root)
# Info in <H10Looper::Loop>: 57.33% entries processed
# Info in <H10Looper::Loop>: Total memory used = 22MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 2000000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a04.root)
# Info in <H10Looper::Loop>: 60.35% entries processed
# Info in <H10Looper::Loop>: Total memory used = 24MB
# Info in <H10Looper::Loop>: Processing entry# 2100000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a04.root)
# Info in <H10Looper::Loop>: 63.37% entries processed
# Info in <H10Looper::Loop>: Total memory used = 36MB
# Info in <H10Looper::Loop>: Processing entry# 2200000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a04.root)
# Info in <H10Looper::Loop>: 66.39% entries processed
# Info in <H10Looper::Loop>: Total memory used = 18MB
# Info in <H10Looper::Loop>: Processing entry# 2300000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a04.root)
# Info in <H10Looper::Loop>: 69.41% entries processed
# Info in <H10Looper::Loop>: Total memory used = -10MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 2400000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a05.root)
# Info in <H10Looper::Loop>: 72.42% entries processed
# Info in <H10Looper::Loop>: Total memory used = -7MB
# Info in <H10Looper::Loop>: Processing entry# 2500000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a05.root)
# Info in <H10Looper::Loop>: 75.44% entries processed
# Info in <H10Looper::Loop>: Total memory used = 27MB
# Info in <H10Looper::Loop>: Processing entry# 2600000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a05.root)
# Info in <H10Looper::Loop>: 78.46% entries processed
# Info in <H10Looper::Loop>: Total memory used = 23MB
# Info in <H10Looper::Loop>: Processing entry# 2700000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a05.root)
# Info in <H10Looper::Loop>: 81.48% entries processed
# Info in <H10Looper::Loop>: Total memory used = 9MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 2800000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a06.root)
# Info in <H10Looper::Loop>: 84.49% entries processed
# Info in <H10Looper::Loop>: Total memory used = -46MB
# Info in <H10Looper::Loop>: Processing entry# 2900000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a06.root)
# Info in <H10Looper::Loop>: 87.51% entries processed
# Info in <H10Looper::Loop>: Total memory used = -47MB
# =4.01,deltaq=0.06,totalQ=4.03qcurr=4.14,qprev=4.08,deltaq=0.06,totalQ=4.09qcurr=4.20,qprev=4.14,deltaq=0.06,totalQ=4.15qcurr=4.26,qprev=4.20,deltaq=0.06,totalQ=4.21qcurr=4.33,qprev=4.26,deltaq=0.06,totalQ=4.28qcurr=4.39,qprev=4.33,deltaq=0.06,totalQ=4.34qcurr=4.45,qprev=4.39,deltaq=0.06,totalQ=4.40qcurr=4.51,qprev=4.45,deltaq=0.06,totalQ=4.46qcurr=4.58,qprev=4.51,deltaq=0.06,totalQ=4.53qcurr=4.64,qprev=4.58,deltaq=0.06,totalQ=4.59qcurr=4.70,qprev=4.64,deltaq=0.06,totalQ=4.65qcurr=4.76,qprev=4.70,deltaq=0.06,totalQ=4.72qcurr=4.83,qprev=4.76,deltaq=0.06,totalQ=4.78qcurr=4.89,qprev=4.83,deltaq=0.06,totalQ=4.84qcurr=4.95,qprev=4.89,deltaq=0.06,totalQ=4.90qcurr=5.02,qprev=4.95,deltaq=0.06,totalQ=4.97qcurr=5.08,qprev=5.02,deltaq=0.06,totalQ=5.03qcurr=5.14,qprev=5.08,deltaq=0.06,totalQ=5.09qcurr=5.20,qprev=5.14,deltaq=0.06,totalQ=5.15qcurr=5.27,qprev=5.20,deltaq=0.06,totalQ=5.22qcurr=5.31,qprev=5.27,deltaq=0.05,totalQ=5.26qcurr=5.37,qprev=5.31,deltaq=0.06,totalQ=5.32qcurr=5.44,qprev=5.37,deltaq=0.07,totalQ=5.39qcurr=5.51,qprev=5.44,deltaq=0.07,totalQ=5.46qcurr=5.57,qprev=5.51,deltaq=0.07,totalQ=5.52qcurr=5.64,qprev=5.57,deltaq=0.07,totalQ=5.59qcurr=5.71,qprev=5.64,deltaq=0.07,totalQ=5.66qcurr=5.78,qprev=5.71,deltaq=0.07,totalQ=5.73qcurr=5.85,qprev=5.78,deltaq=0.07,totalQ=5.80qcurr=5.92,qprev=5.85,deltaq=0.07,totalQ=5.87qcurr=5.99,qprev=5.92,deltaq=0.07,totalQ=5.94qcurr=6.06,qprev=5.99,deltaq=0.07,totalQ=6.01qcurr=6.13,qprev=6.06,deltaq=0.07,totalQ=6.08qcurr=6.20,qprev=6.13,deltaq=0.07,totalQ=6.15qcurr=6.27,qprev=6.20,deltaq=0.07,totalQ=6.22qcurr=6.33,qprev=6.27,deltaq=0.07,totalQ=6.28qcurr=6.40,qprev=6.33,deltaq=0.07,totalQ=6.35qcurr=6.47,qprev=6.40,deltaq=0.07,totalQ=6.42qcurr=6.54,qprev=6.47,deltaq=0.07,totalQ=6.49qcurr=6.61,qprev=6.54,deltaq=0.07,totalQ=6.56qcurr=6.68,qprev=6.61,deltaq=0.07,totalQ=6.63qcurr=6.75,qprev=6.68,deltaq=0.07,totalQ=6.70qcurr=6.82,qprev=6.75,deltaq=0.07,totalQ=6.77qcurr=6.89,qprev=6.82,deltaq=0.07,totalQ=6.84qcurr=6.95,qprev=6.89,deltaq=0.07,totalQ=6.90qcurr=7.02,qprev=6.95,deltaq=0.07,totalQ=6.97qcurr=7.09,qprev=7.02,deltaq=0.07,totalQ=7.04qcurr=7.16,qprev=7.09,deltaq=0.07,totalQ=7.11qcurr=7.23,qprev=7.16,deltaq=0.07,totalQ=7.18qcurr=7.30,qprev=7.23,deltaq=0.07,totalQ=7.25qcurr=7.36,qprev=7.30,deltaq=0.07,totalQ=7.31qcurr=7.43,qprev=7.36,deltaq=0.07,totalQ=7.38qcurr=7.50,qprev=7.43,deltaq=0.07,totalQ=7.45qcurr=7.57,qprev=7.50,deltaq=0.07,totalQ=7.52qcurr=7.64,qprev=7.57,deltaq=0.07,totalQ=7.59qcurr=7.71,qprev=7.64,deltaq=0.07,totalQ=7.66qcurr=7.78,qprev=7.71,deltaq=0.07,totalQ=7.73qcurr=7.85,qprev=7.78,deltaq=0.07,totalQ=7.80qcurr=7.92,qprev=7.85,deltaq=0.07,totalQ=7.87qcurr=7.98,qprev=7.92,deltaq=0.07,totalQ=7.93qcurr=8.05,qprev=7.98,deltaq=0.07,totalQ=8.00qcurr=8.12,qprev=8.05,deltaq=0.07,totalQ=8.07qcurr=8.19,qprev=8.12,deltaq=0.07,totalQ=8.14qcurr=8.26,qprev=8.19,deltaq=0.07,totalQ=8.21qcurr=8.33,qprev=8.26,deltaq=0.07,totalQ=8.28qcurr=8.40,qprev=8.33,deltaq=0.07,totalQ=8.35qcurr=8.47,qprev=8.40,deltaq=0.07,totalQ=8.42qcurr=8.54,qprev=8.47,deltaq=0.07,totalQ=8.49qcurr=8.61,qprev=8.54,deltaq=0.07,totalQ=8.56qcurr=8.68,qprev=8.61,deltaq=0.07,totalQ=8.63qcurr=8.76,qprev=8.68,deltaq=0.07,totalQ=8.71qcurr=8.83,qprev=8.76,deltaq=0.07,totalQ=8.78qcurr=8.90,qprev=8.83,deltaq=0.07,totalQ=8.85qcurr=8.97,qprev=8.90,deltaq=0.07,totalQ=8.92qcurr=9.05,qprev=8.97,deltaq=0.07,totalQ=9.00qcurr=9.12,qprev=9.05,deltaq=0.07,totalQ=9.07qcurr=9.19,qprev=9.12,deltaq=0.07,totalQ=9.14qcurr=9.27,qprev=9.19,deltaq=0.08,totalQ=9.22qcurr=9.34,qprev=9.27,deltaq=0.08,totalQ=9.29qcurr=9.42,qprev=9.34,deltaq=0.07,totalQ=9.37qcurr=9.49,qprev=9.42,deltaq=0.08,totalQ=9.44qcurr=9.57,qprev=9.49,deltaq=0.07,totalQ=9.52qcurr=9.64,qprev=9.57,deltaq=0.07,totalQ=9.59qcurr=9.71,qprev=9.64,deltaq=0.07,totalQ=9.66qcurr=9.78,qprev=9.71,deltaq=0.07,totalQ=9.73qcurr=9.85,qprev=9.78,deltaq=0.07,totalQ=9.80qcurr=9.92,qprev=9.85,deltaq=0.07,totalQ=9.88qcurr=10.00,qprev=9.92,deltaq=0.07,totalQ=9.95qcurr=10.07,qprev=10.00,deltaq=0.07,totalQ=10.02qcurr=1 ...
# Info in <H10Looper::Loop>: 90.53% entries processed
# Info in <H10Looper::Loop>: Total memory used = -19MB
# Info in <H10Looper::Loop>: Processing entry# 3100000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a06.root)
# Info in <H10Looper::Loop>: 93.55% entries processed
# Info in <H10Looper::Loop>: Total memory used = 35MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 3200000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a07.root)
# Info in <H10Looper::Loop>: 96.56% entries processed
# Info in <H10Looper::Loop>: Total memory used = 10MB
# Info in <H10Looper::Loop>: Processing entry# 3300000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37658_pass1.a07.root)
# Info in <H10Looper::Loop>: 99.58% entries processed
# Info in <H10Looper::Loop>: Total memory used = 27MB
# Info in <H10Looper::Loop>: Total memory used = 31MB
#
# 0.29,qprev=10.22,deltaq=0.07,totalQ=10.24qcurr=10.36,qprev=10.29,deltaq=0.07,totalQ=10.31qcurr=10.44,qprev=10.36,deltaq=0.07,totalQ=10.39qcurr=10.51,qprev=10.44,deltaq=0.07,totalQ=10.46qcurr=10.58,qprev=10.51,deltaq=0.07,totalQ=10.53qcurr=10.65,qprev=10.58,deltaq=0.07,totalQ=10.60qcurr=10.72,qprev=10.65,deltaq=0.07,totalQ=10.67qcurr=10.79,qprev=10.72,deltaq=0.07,totalQ=10.74qcurr=10.86,qprev=10.79,deltaq=0.07,totalQ=10.81qcurr=10.93,qprev=10.86,deltaq=0.07,totalQ=10.88qcurr=11.01,qprev=10.93,deltaq=0.08,totalQ=10.96qcurr=11.08,qprev=11.01,deltaq=0.07,totalQ=11.03qcurr=11.15,qprev=11.08,deltaq=0.07,totalQ=11.10qcurr=11.23,qprev=11.15,deltaq=0.07,totalQ=11.18qcurr=11.30,qprev=11.23,deltaq=0.07,totalQ=11.25qcurr=11.37,qprev=11.30,deltaq=0.07,totalQ=11.32qcurr=11.44,qprev=11.37,deltaq=0.07,totalQ=11.39
# Going to process runnum 37659
# >proc_h10 -i /home/trivedia/ongoing/e1f_allruns_h10lst/37659.lst -t e1f:exp:2pi  -p lum -o /data/trivedia/e1f/study_lum/lum_37659.root
# Info in <proc_h10::main()>:
#
# Info in <proc_h10>: Not going to use q2w_elist
#
# Info in <proc_h10>: h10lst=/home/trivedia/ongoing/e1f_allruns_h10lst/37659.lst,h10type=e1f:exp:2pi,procorder=lum,fout=/data/trivedia/e1f/study_lum/lum_37659.root,nentries=1000000000
# Info in <proc_h10::SetupProcs()>: procorder = lum
#
# Collection name='TObjArray', class='TObjArray', size=16
#  TObjString = lum
# Info in <EpProcessor::EpProcessor()>: lum isFirstProc!
#
# Info in <EpProcessor::EpProcessor()>: eid isFirstProc!
#
# Info in <ProcEid::ProcEid()>: dH10.expt==e1f && eidParFileFound=true. Will use goodE()
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Number of entries in Chain =  3217268
# Info in <H10Looper::Loop>: Number of entries to processess =  3217268
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 0(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a01.root)
# Info in <H10Looper::Loop>:  0.00% entries processed
# Info in <H10Looper::Loop>: Total memory used = -16MB
# Info in <H10Looper::Loop>: Processing entry# 100000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a01.root)
# Info in <H10Looper::Loop>:  3.11% entries processed
# Info in <H10Looper::Loop>: Total memory used = -18MB
# Info in <H10Looper::Loop>: Processing entry# 200000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a01.root)
# Info in <H10Looper::Loop>:  6.22% entries processed
# Info in <H10Looper::Loop>: Total memory used = -31MB
# Info in <H10Looper::Loop>: Processing entry# 300000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a01.root)
# Info in <H10Looper::Loop>:  9.32% entries processed
# Info in <H10Looper::Loop>: Total memory used = -32MB
# Info in <H10Looper::Loop>: Processing entry# 400000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a01.root)
# Info in <H10Looper::Loop>: 12.43% entries processed
# Info in <H10Looper::Loop>: Total memory used = -58MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 500000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a02.root)
# Info in <H10Looper::Loop>: 15.54% entries processed
# Info in <H10Looper::Loop>: Total memory used = -34MB
# Info in <H10Looper::Loop>: Processing entry# 600000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a02.root)
# Info in <H10Looper::Loop>: 18.65% entries processed
# Info in <H10Looper::Loop>: Total memory used = -66MB
# Info in <H10Looper::Loop>: Processing entry# 700000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a02.root)
# Info in <H10Looper::Loop>: 21.76% entries processed
# Info in <H10Looper::Loop>: Total memory used = -27MB
# Info in <H10Looper::Loop>: Processing entry# 800000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a02.root)
# Info in <H10Looper::Loop>: 24.87% entries processed
# Info in <H10Looper::Loop>: Total memory used = -19MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 900000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a03.root)
# Info in <H10Looper::Loop>: 27.97% entries processed
# Info in <H10Looper::Loop>: Total memory used = -39MB
# Info in <H10Looper::Loop>: Processing entry# 1000000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a03.root)
# Info in <H10Looper::Loop>: 31.08% entries processed
# Info in <H10Looper::Loop>: Total memory used = -66MB
# Info in <H10Looper::Loop>: Processing entry# 1100000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a03.root)
# Info in <H10Looper::Loop>: 34.19% entries processed
# Info in <H10Looper::Loop>: Total memory used = -6MB
# Info in <H10Looper::Loop>: Processing entry# 1200000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a03.root)
# Info in <H10Looper::Loop>: 37.30% entries processed
# Info in <H10Looper::Loop>: Total memory used = -7MB
# Info in <H10Looper::Loop>: Processing entry# 1300000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a03.root)
# Info in <H10Looper::Loop>: 40.41% entries processed
# Info in <H10Looper::Loop>: Total memory used = -16MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 1400000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a04.root)
# Info in <H10Looper::Loop>: 43.52% entries processed
# Info in <H10Looper::Loop>: Total memory used = -28MB
# Info in <H10Looper::Loop>: Processing entry# 1500000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a04.root)
# Info in <H10Looper::Loop>: 46.62% entries processed
# Info in <H10Looper::Loop>: Total memory used = -22MB
# Info in <H10Looper::Loop>: Processing entry# 1600000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37659_pass1.a04.root)
# Info in <H10Looper::Loop>: 49.73% entries processed
# Info in <H10Looper::Loop>: Total memory used = -34MB
# Reading eid pars from /home/trivedia/CLAS/workspace/ana2pi/eid/eid.exp.out
# ...
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 2300000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a06.root)
# Info in <H10Looper::Loop>: 58.86% entries processed
# Info in <H10Looper::Loop>: Total memory used = -9MB
# Info in <H10Looper::Loop>: Processing entry# 2400000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a06.root)
# Info in <H10Looper::Loop>: 61.42% entries processed
# Info in <H10Looper::Loop>: Total memory used = -51MB
# Info in <H10Looper::Loop>: Processing entry# 2500000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a06.root)
# Info in <H10Looper::Loop>: 63.97% entries processed
# Info in <H10Looper::Loop>: Total memory used = -26MB
# Info in <H10Looper::Loop>: Processing entry# 2600000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a06.root)
# Info in <H10Looper::Loop>: 66.53% entries processed
# Info in <H10Looper::Loop>: Total memory used = 11MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 2700000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a07.root)
# Info in <H10Looper::Loop>: 69.09% entries processed
# Info in <H10Looper::Loop>: Total memory used = -6MB
# Info in <H10Looper::Loop>: Processing entry# 2800000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a07.root)
# Info in <H10Looper::Loop>: 71.65% entries processed
# Info in <H10Looper::Loop>: Total memory used = -25MB
# Info in <H10Looper::Loop>: Processing entry# 2900000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a07.root)
# Info in <H10Looper::Loop>: 74.21% entries processed
# Info in <H10Looper::Loop>: Total memory used = -59MB
# Info in <H10Looper::Loop>: Processing entry# 3000000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a07.root)
# Info in <H10Looper::Loop>: 76.77% entries processed
# Info in <H10Looper::Loop>: Total memory used = -22MB
# Info in <H10Looper::Loop>: Processing entry# 3100000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a07.root)
# Info in <H10Looper::Loop>: 79.33% entries processed
# Info in <H10Looper::Loop>: Total memory used = 6MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 3200000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a08.root)
# Info in <H10Looper::Loop>: 81.89% entries processed
# Info in <H10Looper::Loop>: Total memory used = 0MB
# =7.18,deltaq=0.06,totalQ=5.64qcurr=7.31,qprev=7.24,deltaq=0.06,totalQ=5.71qcurr=7.37,qprev=7.31,deltaq=0.06,totalQ=5.77qcurr=7.43,qprev=7.37,deltaq=0.06,totalQ=5.83qcurr=7.50,qprev=7.43,deltaq=0.06,totalQ=5.90qcurr=7.56,qprev=7.50,deltaq=0.06,totalQ=5.96qcurr=7.59,qprev=7.56,deltaq=0.03,totalQ=5.98qcurr=7.59,qprev=7.59,deltaq=0.00,totalQ=5.98qcurr=7.61,qprev=7.59,deltaq=0.03,totalQ=6.01qcurr=7.66,qprev=7.61,deltaq=0.05,totalQ=6.06qcurr=7.71,qprev=7.66,deltaq=0.06,totalQ=6.11qcurr=7.78,qprev=7.71,deltaq=0.06,totalQ=6.17qcurr=7.84,qprev=7.78,deltaq=0.06,totalQ=6.24qcurr=7.90,qprev=7.84,deltaq=0.06,totalQ=6.30qcurr=7.96,qprev=7.90,deltaq=0.06,totalQ=6.36qcurr=8.03,qprev=7.96,deltaq=0.06,totalQ=6.42qcurr=8.09,qprev=8.03,deltaq=0.06,totalQ=6.49qcurr=8.15,qprev=8.09,deltaq=0.06,totalQ=6.55qcurr=8.21,qprev=8.15,deltaq=0.06,totalQ=6.61qcurr=8.28,qprev=8.21,deltaq=0.06,totalQ=6.68qcurr=8.34,qprev=8.28,deltaq=0.06,totalQ=6.74qcurr=8.40,qprev=8.34,deltaq=0.06,totalQ=6.80qcurr=8.47,qprev=8.40,deltaq=0.06,totalQ=6.86qcurr=8.53,qprev=8.47,deltaq=0.06,totalQ=6.93qcurr=8.59,qprev=8.53,deltaq=0.06,totalQ=6.99qcurr=8.65,qprev=8.59,deltaq=0.06,totalQ=7.05qcurr=8.72,qprev=8.65,deltaq=0.06,totalQ=7.12qcurr=8.78,qprev=8.72,deltaq=0.06,totalQ=7.17qcurr=8.81,qprev=8.78,deltaq=0.04,totalQ=7.21qcurr=8.86,qprev=8.81,deltaq=0.05,totalQ=7.26qcurr=8.92,qprev=8.86,deltaq=0.06,totalQ=7.32qcurr=8.98,qprev=8.92,deltaq=0.06,totalQ=7.38qcurr=9.05,qprev=8.98,deltaq=0.06,totalQ=7.45qcurr=9.11,qprev=9.05,deltaq=0.06,totalQ=7.51qcurr=9.17,qprev=9.11,deltaq=0.06,totalQ=7.57qcurr=9.24,qprev=9.17,deltaq=0.06,totalQ=7.63qcurr=9.30,qprev=9.24,deltaq=0.06,totalQ=7.70qcurr=9.36,qprev=9.30,deltaq=0.06,totalQ=7.76qcurr=9.42,qprev=9.36,deltaq=0.06,totalQ=7.82qcurr=9.49,qprev=9.42,deltaq=0.06,totalQ=7.89qcurr=9.55,qprev=9.49,deltaq=0.06,totalQ=7.95qcurr=9.61,qprev=9.55,deltaq=0.06,totalQ=8.01qcurr=9.68,qprev=9.61,deltaq=0.06,totalQ=8.08qcurr=9.74,qprev=9.68,deltaq=0.06,totalQ=8.14qcurr=9.80,qprev=9.74,deltaq=0.06,totalQ=8.20qcurr=9.87,qprev=9.80,deltaq=0.06,totalQ=8.26qcurr=9.93,qprev=9.87,deltaq=0.06,totalQ=8.33qcurr=9.99,qprev=9.93,deltaq=0.06,totalQ=8.39qcurr=10.05,qprev=9.99,deltaq=0.06,totalQ=8.45qcurr=10.12,qprev=10.05,deltaq=0.06,totalQ=8.51qcurr=10.18,qprev=10.12,deltaq=0.06,totalQ=8.58qcurr=10.24,qprev=10.18,deltaq=0.06,totalQ=8.64qcurr=10.30,qprev=10.24,deltaq=0.06,totalQ=8.70qcurr=10.37,qprev=10.30,deltaq=0.06,totalQ=8.77qcurr=10.43,qprev=10.37,deltaq=0.06,totalQ=8.83qcurr=10.49,qprev=10.43,deltaq=0.06,totalQ=8.89qcurr=10.55,qprev=10.49,deltaq=0.06,totalQ=8.95qcurr=10.62,qprev=10.55,deltaq=0.06,totalQ=9.02qcurr=10.68,qprev=10.62,deltaq=0.06,totalQ=9.08qcurr=10.74,qprev=10.68,deltaq=0.06,totalQ=9.14qcurr=10.81,qprev=10.74,deltaq=0.06,totalQ=9.21qcurr=10.87,qprev=10.81,deltaq=0.06,totalQ=9.27qcurr=10.93,qprev=10.87,deltaq=0.06,totalQ=9.33qcurr=10.99,qprev=10.93,deltaq=0.06,totalQ=9.39qcurr=11.06,qprev=10.99,deltaq=0.06,totalQ=9.46qcurr=11.12,qprev=11.06,deltaq=0.06,totalQ=9.52qcurr=11.18,qprev=11.12,deltaq=0.06,totalQ=9.58qcurr=11.25,qprev=11.18,deltaq=0.06,totalQ=9.65qcurr=11.31,qprev=11.25,deltaq=0.06,totalQ=9.71qcurr=11.37,qprev=11.31,deltaq=0.06,totalQ=9.77qcurr=11.44,qprev=11.37,deltaq=0.06,totalQ=9.84qcurr=11.50,qprev=11.44,deltaq=0.06,totalQ=9.90qcurr=11.56,qprev=11.50,deltaq=0.06,totalQ=9.96qcurr=11.63,qprev=11.56,deltaq=0.06,totalQ=10.02qcurr=11.69,qprev=11.63,deltaq=0.06,totalQ=10.09qcurr=11.75,qprev=11.69,deltaq=0.06,totalQ=10.15qcurr=11.81,qprev=11.75,deltaq=0.06,totalQ=10.21qcurr=11.88,qprev=11.81,deltaq=0.06,totalQ=10.28qcurr=11.94,qprev=11.88,deltaq=0.06,totalQ=10.34qcurr=12.00,qprev=11.94,deltaq=0.06,totalQ=10.40qcurr=12.06,qprev=12.00,deltaq=0.06,totalQ=10.46qcurr=12.13,qprev=12.06,deltaq=0.06,totalQ=10.53qcurr=12.19,qprev=12.13,deltaq=0.06,totalQ=10.59qcurr=12.25,qprev=12.19,deltaq=0.06,totalQ=10.65qcurr=12.32,qprev=12.25,deltaq=0.06,totalQ=10.72qcurr=12.38,qprev=12.32,deltaq=0.06,totalQ=10.78qcurr=12.44,qprev=12.38,deltaq=0.06,totalQ=10.84qcurr=12.5 ...
# Info in <H10Looper::Loop>: 84.45% entries processed
# Info in <H10Looper::Loop>: Total memory used = -53MB
# Info in <H10Looper::Loop>: Processing entry# 3400000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a08.root)
# Info in <H10Looper::Loop>: 87.00% entries processed
# Info in <H10Looper::Loop>: Total memory used = -3MB
# Info in <H10Looper::Loop>: Processing entry# 3500000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a08.root)
# Info in <H10Looper::Loop>: 89.56% entries processed
# Info in <H10Looper::Loop>: Total memory used = -33MB
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_stat
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_sect
# Error in <TTree::SetBranchStatus>: unknown branch -> nphe
# Error in <TTree::SetBranchStatus>: unknown branch -> evntid
# Error in <TTree::SetBranchStatus>: unknown branch -> npart
# Error in <TTree::SetBranchStatus>: unknown branch -> tr_time
# Error in <TTree::SetBranchStatus>: unknown branch -> m
# Error in <TTree::SetBranchStatus>: unknown branch -> b
# Error in <TTree::SetBranchStatus>: unknown branch -> vx
# Error in <TTree::SetBranchStatus>: unknown branch -> vy
# Error in <TTree::SetBranchStatus>: unknown branch -> vz
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_xsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_ysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_zsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cxsc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_cysc
# Error in <TTree::SetBranchStatus>: unknown branch -> dc_czsc
# Error in <TTree::SetBranchStatus>: unknown branch -> etot
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_ei
# Error in <TTree::SetBranchStatus>: unknown branch -> ec_eo
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_x
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_y
# Error in <TTree::SetBranchStatus>: unknown branch -> ech_z
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_t
# Error in <TTree::SetBranchStatus>: unknown branch -> sc_r
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_part
# Error in <TTree::SetBranchStatus>: unknown branch -> cc_segm
# Info in <H10Looper::Loop>: Processing entry# 3600000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a09.root)
# Info in <H10Looper::Loop>: 92.12% entries processed
# Info in <H10Looper::Loop>: Total memory used = -33MB
# Info in <H10Looper::Loop>: Processing entry# 3700000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a09.root)
# Info in <H10Looper::Loop>: 94.68% entries processed
# Info in <H10Looper::Loop>: Total memory used = -20MB
# Info in <H10Looper::Loop>: Processing entry# 3800000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a09.root)
# Info in <H10Looper::Loop>: 97.24% entries processed
# Info in <H10Looper::Loop>: Total memory used = 6MB
# Info in <H10Looper::Loop>: Processing entry# 3900000(file=/data/trivedia/e1f/2pi/exp/h10skim/root_37661_pass1.a09.root)
# Info in <H10Looper::Loop>: 99.80% entries processed
# Info in <H10Looper::Loop>: Total memory used = -95MB
# Info in <H10Looper::Loop>: Total memory used = -94MB
#
# 3,qprev=12.57,deltaq=0.06,totalQ=11.03qcurr=12.69,qprev=12.63,deltaq=0.06,totalQ=11.09qcurr=12.76,qprev=12.69,deltaq=0.06,totalQ=11.16qcurr=12.82,qprev=12.76,deltaq=0.06,totalQ=11.22qcurr=12.88,qprev=12.82,deltaq=0.06,totalQ=11.28qcurr=12.95,qprev=12.88,deltaq=0.06,totalQ=11.35qcurr=13.01,qprev=12.95,deltaq=0.06,totalQ=11.41qcurr=13.07,qprev=13.01,deltaq=0.06,totalQ=11.47qcurr=13.14,qprev=13.07,deltaq=0.06,totalQ=11.53qcurr=13.20,qprev=13.14,deltaq=0.06,totalQ=11.60qcurr=13.26,qprev=13.20,deltaq=0.06,totalQ=11.66qcurr=13.32,qprev=13.26,deltaq=0.06,totalQ=11.72qcurr=13.39,qprev=13.32,deltaq=0.06,totalQ=11.79qcurr=13.45,qprev=13.39,deltaq=0.06,totalQ=11.85qcurr=13.51,qprev=13.45,deltaq=0.06,totalQ=11.91qcurr=13.57,qprev=13.51,deltaq=0.06,totalQ=11.97qcurr=13.64,qprev=13.57,deltaq=0.06,totalQ=12.04qcurr=13.70,qprev=13.64,deltaq=0.06,totalQ=12.10qcurr=13.76,qprev=13.70,deltaq=0.06,totalQ=12.16qcurr=13.83,qprev=13.76,deltaq=0.06,totalQ=12.23qcurr=13.89,qprev=13.83,deltaq=0.06,totalQ=12.29qcurr=13.95,qprev=13.89,deltaq=0.06,totalQ=12.35qcurr=14.01,qprev=13.95,deltaq=0.06,totalQ=12.41qcurr=14.08,qprev=14.01,deltaq=0.06,totalQ=12.48qcurr=14.14,qprev=14.08,deltaq=0.06,totalQ=12.54qcurr=14.20,qprev=14.14,deltaq=0.06,totalQ=12.60qcurr=14.27,qprev=14.20,deltaq=0.06,totalQ=12.67qcurr=14.33,qprev=14.27,deltaq=0.06,totalQ=12.73qcurr=14.39,qprev=14.33,deltaq=0.06,totalQ=12.79qcurr=14.45,qprev=14.39,deltaq=0.06,totalQ=12.85qcurr=14.52,qprev=14.45,deltaq=0.06,totalQ=12.92qcurr=14.58,qprev=14.52,deltaq=0.06,totalQ=12.98qcurr=14.64,qprev=14.58,deltaq=0.06,totalQ=13.04qcurr=14.71,qprev=14.64,deltaq=0.06,totalQ=13.10qcurr=14.77,qprev=14.71,deltaq=0.06,totalQ=13.17qcurr=14.83,qprev=14.77,deltaq=0.06,totalQ=13.23qcurr=14.89,qprev=14.83,deltaq=0.06,totalQ=13.29qcurr=14.96,qprev=14.89,deltaq=0.06,totalQ=13.36qcurr=15.01,qprev=14.96,deltaq=0.06,totalQ=13.41qcurr=15.01,qprev=15.01,deltaq=0.00,totalQ=13.41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4bf8da082448> in <module>()
#      19     print ">%s"%cmd
#      20     p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
# ---> 21     stdout=p.stdout.read()
#      22     #stderr=p.stderr
#      23     print stdout#,stderr
#
# KeyboardInterrupt:
# Going to process runnum 37662
# >proc_h10 -i /home/trivedia/ongoing/e1f_allruns_h10lst/37662.lst -t e1f:exp:2pi  -p lum -o /data/trivedia/e1f/study_lum/lum_37662.root

# %%
ff=open('lum.txt', 'w')
lumdl=glob.glob(os.path.join(os.environ['STUDY_LUM_DATADIR'],"*.root"))
lumdl=sort(lumdl)
print lumdl
for lumd in lumdl:
    runnum=int(lumd.split("/")[5].split(".")[0])
    print runnum
    f=ROOT.TFile(lumd)
    print f.GetName()
    hevtsum=f.Get("lum/hevtsum")
    hQ=f.Get("lum/Q")
    print hevtsum.GetName()
    q=hQ.GetBinContent(1)
    Ntrigger=hevtsum.GetBinContent(1)
    Ngoode=hevtsum.GetBinContent(2)
    ff.write("%d %.2f %d %d\n"%(runnum,q,Ntrigger,Ngoode))
ff.close()
# Out:
# ['/data/trivedia/e1f/study_lum/37658.root'
#  '/data/trivedia/e1f/study_lum/37659.root'
#  '/data/trivedia/e1f/study_lum/37661.root'
#  '/data/trivedia/e1f/study_lum/37662.root']
# 37658
# /data/trivedia/e1f/study_lum/37658.root
# hevtsum
# 37659
# /data/trivedia/e1f/study_lum/37659.root
# hevtsum
# 37661
# /data/trivedia/e1f/study_lum/37661.root
# hevtsum
# 37662
# /data/trivedia/e1f/study_lum/37662.root
# hevtsum

# %%
ff=open('lum.txt')
runnuml=[]
norm_Ntrigger=[]
norm_Ngoode=[]
for l in ff.readlines():
    #print l
    dl=l.split(" ")
    runnum=int(dl[0].strip())
    q=float(dl[1].strip())
    Ntrigger=int(dl[2].strip())
    Ngoode=int(dl[3].strip())
    print runnum,q,Ntrigger,Ngoode
    runnuml.append(runnum)
    norm_Ntrigger.append(Ntrigger/q)
    norm_Ngoode.append(Ngoode/q)
fig,axs=plt.subplots(nrows=1,ncols=2)
axs[0].scatter(runnuml,norm_Ntrigger)
axs[1].scatter(runnuml,norm_Ngoode)
# Out:
# 37658 11.39 3313868 239
# 37659 11.01 3217268 239
# 37661 13.41 3907822 264
# 37662 32.07 9321356 582

# %%
from subprocess import Popen, PIPE, STDOUT
cmd = 'ls /etc/fstab /etc/non-existent-file'
p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
stdout=p.stdout.read()
#stderr=p.stderr
print stdout#,stderr
# Out:
# ls: cannot access /etc/non-existent-file: No such file or directory
# /etc/fstab

# %%
import atlib as t
import os
from root_numpy import root2array, root2rec, tree2rec
#r=os.path.join(os.environ['H10DIR_EXP'],'h10-sample','root_37658_pass1.a00.root')
r=os.path.join(os.environ['H10DIR_EXP'],'h10-sample','root_37658_pass1.*.root')
d=pd.DataFrame(root2array(r,'h10',branches=['q_l','evntid']))

# %%
print d.head()
# Out:
#    q_l   evntid
# 0    0  1279212
# 1    0  1279213
# 2    0  1279214
# 3    0  1279215
# 4    0  1279216

# %%
x=d['evntid']
y=d['q_l']
plt.scatter(x,y)

# %%
r=d['q_l']
print r[44531]
print r[44532]
print r[44500:44532]
# Out:
# 13.7696
# 13.7696
# 44500    13.769597
# 44501    13.769597
# 44502    13.769597
# 44503    13.769597
# 44504    13.769597
# 44505    13.769597
# 44506    13.769597
# 44507    13.769597
# 44508    13.769597
# 44509    13.769597
# 44510    13.769597
# 44511    13.769597
# 44512    13.769597
# 44513    13.769597
# 44514    13.769597
# 44515    13.769597
# 44516    13.769597
# 44517    13.769597
# 44518    13.769597
# 44519    13.769597
# 44520    13.769597
# 44521    13.769597
# 44522    13.769597
# 44523    13.769597
# 44524    13.769597
# 44525    13.769597
# 44526    13.769597
# 44527    13.769597
# 44528    13.769597
# 44529    13.769597
# 44530    13.769597
# 44531    13.769597
# Name: q_l, dtype: float32
