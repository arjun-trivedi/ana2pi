# %%
from __future__ import division
import rootnotes as rn
from rootpy.plotting import Hist, HistStack, Legend, Canvas
from rootpy import asrootpy
chain=ROOT.TChain("h10")
def get_vz_canvas(lcn,runnum):
#rint os.environ['H10DIR_EXP_E16']
    #chain.Add("%s/h10-sample/ntp_%d*"%(os.environ['H10DIR_EXP_E16'],runnum))
    chain.Add("%s/*%d*"%(lcn,runnum))
    arr=chain.GetListOfFiles()
    for i in range (arr.GetLast()+1):
        print arr.At(i).GetTitle()
    c=rn.default_canvas()
    chain.Draw("vz[0]>>hvz(100,-12,6)","id[0]==11 && dc[0]>0 && cc[0]>0 && ec[0]>0 && sc[0]>0")
    htmp=ROOT.gDirectory.Get("hvz")
    htmp.SetName("%d"%runnum)
    return c

def get_vz_hist(lcn,runnum):
#rint os.environ['H10DIR_EXP_E16']
    #chain.Add("%s/h10-sample/ntp_%d*"%(os.environ['H10DIR_EXP_E16'],runnum))
    chain.Add("%s/*%d*"%(lcn,runnum))
    arr=chain.GetListOfFiles()
    for i in range (arr.GetLast()+1):
        print arr.At(i).GetTitle()
    c=rn.default_canvas()
    chain.Draw("vz[0]>>hvz(100,-12,6)","id[0]==11 && dc[0]>0 && cc[0]>0 && ec[0]>0 && sc[0]>0")
    htmp=ROOT.gDirectory.Get("hvz")
    htmp.SetName("%d"%runnum)
    return htmp

# %%
c=get_vz_canvas("%s/e16_etgt_run_files"%os.environ['H10DIR_EXP_E16_2'],30825)
c
# Out:
# INFO:ROOT.TCanvas.Print:png file /tmp/tmpZpeSTU.png has been created
# /home/trivedia/data/e16/2pi/exp/e16_etgt_run_files/ntp_30825_pass1.a00.root
# /home/trivedia/data/e16/2pi/exp/e16_etgt_run_files/ntp_30825_pass1.a01.root
# /home/trivedia/data/e16/2pi/exp/e16_etgt_run_files/ntp_30825_pass1.a02.root
# /home/trivedia/data/e16/2pi/exp/e16_etgt_run_files/ntp_30825_pass1.a03.root
# /home/trivedia/data/e16/2pi/exp/e16_etgt_run_files/ntp_30825_pass1.a04.root
# /home/trivedia/data/e16/2pi/exp/e16_etgt_run_files/ntp_30825_pass1.a05.root
# <ROOT.TCanvas object ("icanvas") at 0x4353e40>

# %%
c=get_vz_canvas("%s/h10-sample"%os.environ['H10DIR_EXP_E16'],30675)
c
# Out:
# INFO:ROOT.TCanvas.Print:png file /tmp/tmpLc_6cX.png has been created
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a00.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a01.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a02.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a03.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a04.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a05.00.root
# <ROOT.TCanvas object ("icanvas") at 0x35d1a80>

# %%
c1=get_vz_canvas("%s/h10-sample"%os.environ['H10DIR_EXP_E16'],30676)
c1
# Out:
# INFO:ROOT.TCanvas.Print:png file /tmp/tmpMQrJwQ.png has been created
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a00.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a01.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a02.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a03.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a04.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a05.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a00.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a01.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a02.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a03.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a04.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a05.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a06.00.root
# ...

# %%
h30675=get_vz_hist("%s/h10-sample"%os.environ['H10DIR_EXP_E16'],30675)
h30676=get_vz_hist("%s/h10-sample"%os.environ['H10DIR_EXP_E16'],30676)
# Out:
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a00.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a01.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a02.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a03.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a04.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a05.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a00.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a01.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a02.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a03.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a04.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30675_pass1.a05.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a00.00.root
# /data/trivedia/e16/2pi/exp/h10-sample/ntp_30676_pass1.a01.00.root
# ...

# %%
h30675=asrootpy(h30675)
fig = plt.figure(figsize=(7, 5), dpi=100)
axes = plt.axes()
rplt.errorbar(h30675, xerr=False, emptybins=False, axes=axes)
# Out:
# <Container object of 3 artists>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
fig,axs=plt.subplots(figsize=(12,8),nrows=2,ncols=1)
fig.subplots_adjust(hspace=.5)
rplt.errorbar(h30675, xerr=False, emptybins=False, axes=axs[0])
# Out:
# <Container object of 3 artists>
