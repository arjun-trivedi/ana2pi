# %%
import study_MMs_tools as t
t.init(['q2w2'],0.6,0.025,[2],True,
     ['mmppip'],
     [(0.0,0.5)],
     [(-0.03,0.03)])
# Out:
# dbg:mcor= True
# dbg:mcor= True
# dbg:here
# dbg:using d2pi_yesmomcorr.root Variables to import directly into DataFrame= ['top', 'Q2', 'mmppip', 'W']
# Variables to be added later to the DataFrame []
# Variables to import directly into DataFrame=
#  ['top', 'Q2', 'mmppip', 'W']
# Variables to be added later to the DataFrame []
# *** Going to keep only
#  [2] for dER and dSR ***
# Evaluating (dER['top']==2) ...
# 3     2
# 6     2
# 7     2
# 9     2
# 10    2
# Name: top, dtype: int32
# Done
# Evaluating (dSR['top']==2) ...
# 0    2
# 3    2
# 4    2
# 5    2
# 6    2
# Name: top, dtype: int32
# Done
# *** Q2 binning ***
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.8800', '2.4800']
# *** W binning ***
# NWBINS=26,WBINW=0.0250 GeV
# ['1.2600', '1.2850', '1.3100', '1.3350', '1.3600', '1.3850', '1.4100', '1.4350', '1.4600', '1.4850', '1.5100', '1.5350', '1.5600', '1.5850', '1.6100', '1.6350', '1.6600', '1.6850', '1.7100', '1.7350', '1.7600', '1.7850', '1.8100', '1.8350', '1.8600', '1.8850', '1.9100']
# *** Q2 binning ***
# NQ2BINS=1,Q2BINW=0.6000 GeV^2
# ['1.8800', '2.4800']
# *** W binning ***
# NWBINS=26,WBINW=0.0250 GeV
# ['1.2600', '1.2850', '1.3100', '1.3350', '1.3600', '1.3850', '1.4100', '1.4350', '1.4600', '1.4850', '1.5100', '1.5350', '1.5600', '1.5850', '1.6100', '1.6350', '1.6600', '1.6850', '1.7100', '1.7350', '1.7600', '1.7850', '1.8100', '1.8350', '1.8600', '1.8850', '1.9100']
# OUTDIR=/home/trivedia/CLAS/workspace/ana2pi/sub_studies/study_MMs/q2w2
# HOFT= [Hist2D('mmppip_OFT')]
# HRES= [Hist2D('mmppip_RES')]

# %%
t.plot_q2w()

# %%
t.plot_mm('mmppip')
plt.vlines(0.139,plt.ylim()[0],plt.ylim()[1],colors='g',linestyles='dashed',linewidth=2)
plt.vlines(0.145,plt.ylim()[0],plt.ylim()[1],colors='b',linestyles='dashed',linewidth=2)
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.Print] eps file test.eps has been created
# (dER['W']>=0.000000)&(dER['W']<2.000000)
# (dSR['W']>=0.000000)&(dSR['W']<2.000000)

# %%
t.plot_res(min_entries=500,use_frange=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-5122da02d3d9> in <module>()
# ----> 1 t.plot_res(min_entries=500,use_frange=True)
#
# AttributeError: 'module' object has no attribute 'plot_res'

# %%
t.plot_electron_diagnostics()
# Out:
# debug= ['theta', 'p'] 1 theta_e p_e
# debug=
#  ['theta', 'p'] 2 Q2 theta_e
# debug=
#  ['theta', 'p'] 3 Q2 p_e
# debug=
#  ['theta', 'p'] 4 W theta_e
# debug=
#  ['theta', 'p'] 5 W p_e
# debug=
#  ['px', 'py'] 6 px_e py_e
# debug=
#  ['px', 'py'] 7 Q2 px_e
# debug=
#  ['px', 'py'] 8 Q2 py_e
# debug=
#  ['px', 'py'] 9 W px_e
# debug=
#  ['px', 'py'] 10 W py_e
